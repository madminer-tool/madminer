# %% [markdown]
# # Appendix 4: Likelihood Module: no systematics
#
# Johann Brehmer, Felix Kling, Irina Espejo, and Kyle Cranmer 2018-2019

# %% [markdown]
# In this notebook, we use the Likelihood class for a process without any systematics.

# %% [markdown]
# ## 0. Preparations

# %%
import sys
import os

madminer_src_path = "/Users/felixkling/Documents/GitHub/madminer"
sys.path.append(madminer_src_path)

import logging
import numpy as np
import time
import matplotlib
from matplotlib import pyplot as plt

# %matplotlib inline

# MadMiner output
logging.basicConfig(
    format="%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s",
    datefmt="%H:%M",
    level=logging.INFO,
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

from madminer import (
    NeuralLikelihood,
    HistoLikelihood,
    project_log_likelihood,
    profile_log_likelihood,
)
from madminer import AsymptoticLimits, plot_pvalue_limits

# %% [markdown]
# We define the grid and luminosity

# %%
grid_ranges = [(-1, 1.0), (-1, 1.0)]
grid_resolutions = [10, 10]

# %%
lumi = 300.0 * 1000.0
n_asimov = 10000
n_histo_toys = 50000

# %%
do_load = True

if do_load:
    p_values, mle, durations = np.load("limits/c1.npy")
else:
    p_values = {}
    mle = {}
    durations = {}

# %% [markdown]
# ## 1. Using AsymptoticLimits class

# %% [markdown]
# For comparisson, let's use the `AsymptoticLimits` class again.

# %%
limits = AsymptoticLimits("data/lhe_data_shuffled.h5")
# Out:
# 20:04 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:04 madminer.analysis    INFO    Found 2 parameters
# 20:04 madminer.analysis    INFO    Did not find nuisance parameters
# 20:04 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:04 madminer.analysis    INFO    Found 3 observables
# 20:04 madminer.analysis    INFO    Found 539913 events
# 20:04 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:04 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:04 madminer.analysis    INFO    Did not find nuisance morphing setup

# %% [markdown]
# Now we calculate the limits for the choosen grid using
# - the full likelihood ratio estimated by the ALICES method
# - the score estimated using the SALLY method
# - a "pt_j1" histogram with fixed bins
# - the rate

# %% [markdown]
# ### a) ALICES

# %%
start_time = time.time()
theta_grid, p_values_expected, best_fit_expected, llr_kin, _, _ = limits.expected_limits(
    mode="ml",
    model_file="models/alices",
    theta_true=[0.0, 0.0],
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
    luminosity=lumi,
    include_xsec=False,
    n_asimov=n_asimov,
)
duration = time.time() - start_time

p_values["AL: ALICES"] = p_values_expected
mle["AL: ALICES"] = best_fit_expected
durations["AL: ALICES"] = duration
# Out:
# 20:04 madminer.limits      INFO    Generating Asimov data
# 20:04 madminer.limits      INFO    Expected events: 313.1522825343162
# 20:04 madminer.limits      INFO    Calculating p-values for 313.1522825343162 expected events in mode ml without rate information
# 20:04 madminer.limits      INFO    Evaluating likelihood on a regular grid with 100 parameter points
# 20:04 madminer.limits      INFO    Loading kinematic likelihood ratio estimator
# 20:04 madminer.ml          INFO    Loading model from models/alices
# 20:04 madminer.limits      INFO    Calculating kinematic log likelihood ratio with estimator
# 20:04 madminer.limits      INFO    Calculating p-values

# %% [markdown]
# ### b) SALLY

# %%
start_time = time.time()
theta_grid, p_values_expected, best_fit_expected, llr_kin, _, _ = limits.expected_limits(
    mode="sally",
    model_file="models/sally",
    theta_true=[0.0, 0.0],
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
    luminosity=lumi,
    include_xsec=False,
    n_asimov=n_asimov,
    n_histo_toys=n_histo_toys,
    hist_bins=[5, 5],
)
duration = time.time() - start_time

p_values["AL: SALLY"] = p_values_expected
mle["AL: SALLY"] = best_fit_expected
durations["AL: SALLY"] = duration
# Out:
# 20:04 madminer.limits      INFO    Generating Asimov data
# 20:04 madminer.limits      INFO    Expected events: 313.1522825343162
# 20:04 madminer.limits      INFO    Calculating p-values for 313.1522825343162 expected events in mode sally without rate information
# 20:04 madminer.limits      INFO    Evaluating likelihood on a regular grid with 100 parameter points
# 20:04 madminer.limits      INFO    Loading score estimator and setting all components up as summary statistics
# 20:04 madminer.ml          INFO    Loading model from models/sally
# 20:04 madminer.limits      INFO    Creating histograms of 2 summary statistics. Using [5, 5] bins each, or 25 in total.
# 20:04 madminer.limits      INFO    Determining fixed adaptive histogram binning for all points on grid
# 20:04 madminer.limits      INFO    Calculating kinematic log likelihood with histograms
# 20:04 madminer.limits      INFO    Calculating p-values

# %% [markdown]
# ### c) Histogram

# %%
start_time = time.time()
theta_grid, p_values_expected, best_fit_expected, llr_kin, _, _ = limits.expected_limits(
    mode="histo",
    hist_vars=["pt_j1"],
    hist_bins=[[20, 100, 200, 300, 400, 500]],
    theta_true=[0.0, 0.0],
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
    luminosity=lumi,
    include_xsec=False,
    n_asimov=n_asimov,
    n_histo_toys=n_histo_toys,
)
duration = time.time() - start_time

p_values["AL: Histo"] = p_values_expected
mle["AL: Histo"] = best_fit_expected
durations["AL: Histo"] = duration
# Out:
# 20:04 madminer.limits      INFO    Generating Asimov data
# 20:04 madminer.limits      INFO    Expected events: 313.1522825343162
# 20:04 madminer.limits      INFO    Calculating p-values for 313.1522825343162 expected events in mode histo without rate information
# 20:04 madminer.limits      INFO    Evaluating likelihood on a regular grid with 100 parameter points
# 20:04 madminer.limits      INFO    Setting up standard summary statistics
# 20:04 madminer.limits      INFO    Creating histograms of 1 summary statistics. Using [5] bins each, or 5 in total.
# 20:04 madminer.limits      INFO    Calculating kinematic log likelihood with histograms
# 20:04 madminer.limits      INFO    Calculating p-values

# %% [markdown]
# ### d) Rate

# %%
start_time = time.time()
theta_grid, p_values_expected, best_fit_expected, llr_kin, _, _ = limits.expected_limits(
    mode="rate",
    theta_true=[0.0, 0.0],
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
    luminosity=lumi,
    include_xsec=True,
)
duration = time.time() - start_time

p_values["AL: Rate"] = p_values_expected
mle["AL: Rate"] = best_fit_expected
durations["AL: Rate"] = duration
# Out:
# 20:04 madminer.limits      INFO    Generating Asimov data
# 20:04 madminer.limits      INFO    Expected events: 313.1522825343162
# 20:04 madminer.limits      INFO    Calculating p-values for 313.1522825343162 expected events in mode rate including rate information
# 20:04 madminer.limits      INFO    Evaluating likelihood on a regular grid with 100 parameter points
# 20:04 madminer.limits      INFO    Calculating rate log likelihood
# 20:04 madminer.limits      INFO    Calculating p-values

# %% [markdown]
# ## 2. Using Likelihood class - Weighted

# %% [markdown]
# We can also use the new Likelihood class to obtain limits. There are to main classes, the `NeuralLikelihood` and `HistoLikelihood` class. First, let's initialize both classes

# %%
neurallikelihood = NeuralLikelihood("data/lhe_data_shuffled.h5")
histolikelihood = HistoLikelihood("data/lhe_data_shuffled.h5")
# Out:
# 20:04 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:04 madminer.analysis    INFO    Found 2 parameters
# 20:04 madminer.analysis    INFO    Did not find nuisance parameters
# 20:04 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:04 madminer.analysis    INFO    Found 3 observables
# 20:04 madminer.analysis    INFO    Found 539913 events
# 20:04 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:04 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:04 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:04 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:04 madminer.analysis    INFO    Found 2 parameters
# 20:04 madminer.analysis    INFO    Did not find nuisance parameters
# 20:04 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:04 madminer.analysis    INFO    Found 3 observables
# 20:04 madminer.analysis    INFO    Found 539913 events
# 20:04 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:04 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:04 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:04 madminer.analysis    INFO    Did not find nuisance morphing setup

# %% [markdown]
# We can now create a function which returns the expected negative log likelihood $-\mathrm{E}[\log p(x|\theta) | \theta_{\text{true}}]$ using the function `create_expected_negative_log_likelihood()`. This function is evaluated in a grid using `project_log_likelihood()`. Let us again do this for ALICES, SALLY, a histogram and the rate.
#
# **Note:** Here we use the `sampled` mode when calculating the likelihood function. This means that at every point we separatly evaulate the rate and sample a set of events to fill histograms. This setup is therefore expected to be slow.

# %% [markdown]
# ### a) ALICES

# %%
start_time = time.time()
nll_alices = neurallikelihood.create_expected_negative_log_likelihood(
    n_asimov=n_asimov,
    include_xsec=False,
    luminosity=lumi,
    theta_true=np.array([0, 0]),
    nu_true=None,
    model_file="models/alices",
)

theta_grid, p_values_expected, best_fit_expected, llr = project_log_likelihood(
    negative_log_likelihood=nll_alices,
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
)
duration = time.time() - start_time

p_values["LHS: ALICES"] = p_values_expected
mle["LHS: ALICES"] = best_fit_expected
durations["LHS: ALICES"] = duration
# Out:
# 20:04 madminer.ml          INFO    Loading model from models/alices

# %% [markdown]
# ### b) SALLY

# %%
start_time = time.time()
nll_sally = histolikelihood.create_expected_negative_log_likelihood(
    n_asimov=n_asimov,
    include_xsec=False,
    luminosity=lumi,
    theta_true=np.array([0, 0]),
    nu_true=None,
    score_components=[0, 1],
    model_file="models/sally",
    hist_bins=[5, 5],
    mode="sampled",
    n_histo_toys=n_histo_toys,
)

theta_grid, p_values_expected, best_fit_expected, llr = project_log_likelihood(
    negative_log_likelihood=nll_sally,
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
)
duration = time.time() - start_time

p_values["LHS: SALLY"] = p_values_expected
mle["LHS: SALLY"] = best_fit_expected
durations["LHS: SALLY"] = duration
# Out:
# 20:04 madminer.ml          INFO    Loading model from models/sally
# 20:04 madminer.likelihood  INFO    Setting up standard summary statistics
# 20:04 madminer.likelihood  INFO    Setting up binning
# 20:05 madminer.likelihood  INFO    Use binning: [array([-6.84291836, -0.14816707,  0.09972289,  0.22996766,  0.30907326,
#         0.37738783]), array([-3.41586907, -0.33438505, -0.1014865 ,  0.11385787,  0.34599706,
#         3.67435363])]
# 20:05 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:05 madminer.analysis    INFO    Found 2 parameters
# 20:05 madminer.analysis    INFO    Did not find nuisance parameters
# 20:05 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:05 madminer.analysis    INFO    Found 3 observables
# 20:05 madminer.analysis    INFO    Found 539913 events
# 20:05 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:05 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:05 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:05 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1. -1.]
# 20:05 madminer.sampling    INFO    Starting sampling serially
# 20:05 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:05 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-1. -1.]: (0.001829 +/- 0.000238) pb (12.988401897209778 %). Skipping these warnings in the future...
# 20:05 madminer.sampling    INFO    Effective number of samples: mean 188.4528978580944, with individual thetas ranging from 188.45289785809442 to 188.45289785809442
# 20:05 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:05 madminer.analysis    INFO    Found 2 parameters
# 20:05 madminer.analysis    INFO    Did not find nuisance parameters
# 20:05 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:05 madminer.analysis    INFO    Found 3 observables
# 20:05 madminer.analysis    INFO    Found 539913 events
# 20:05 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:05 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:05 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:05 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.         -0.77777778]
# 20:05 madminer.sampling    INFO    Starting sampling serially
# 20:05 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:05 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-1.        -0.7777778]: (0.001745 +/- 0.000213) pb (12.20963321703818 %). Skipping these warnings in the future...
# 20:05 madminer.sampling    INFO    Effective number of samples: mean 231.86820313505046, with individual thetas ranging from 231.86820313505046 to 231.86820313505046
# 20:05 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:05 madminer.analysis    INFO    Found 2 parameters
# 20:05 madminer.analysis    INFO    Did not find nuisance parameters
# 20:05 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:05 madminer.analysis    INFO    Found 3 observables
# 20:05 madminer.analysis    INFO    Found 539913 events
# 20:05 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:05 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:05 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:05 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.         -0.55555556]
# 20:05 madminer.sampling    INFO    Starting sampling serially
# 20:05 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:05 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-1.        -0.5555556]: (0.001682 +/- 0.000188) pb (11.190468219271528 %). Skipping these warnings in the future...
# 20:05 madminer.sampling    INFO    Effective number of samples: mean 292.10694400103097, with individual thetas ranging from 292.10694400103085 to 292.10694400103085
# 20:05 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:05 madminer.analysis    INFO    Found 2 parameters
# 20:05 madminer.analysis    INFO    Did not find nuisance parameters
# 20:05 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:05 madminer.analysis    INFO    Found 3 observables
# 20:05 madminer.analysis    INFO    Found 539913 events
# 20:05 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:05 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:05 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:05 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:05 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.         -0.33333333]
# 20:05 madminer.sampling    INFO    Starting sampling serially
# 20:05 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:05 madminer.sampling    INFO    Effective number of samples: mean 372.52573958188566, with individual thetas ranging from 372.52573958188566 to 372.52573958188566
# 20:06 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:06 madminer.analysis    INFO    Found 2 parameters
# 20:06 madminer.analysis    INFO    Did not find nuisance parameters
# 20:06 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:06 madminer.analysis    INFO    Found 3 observables
# 20:06 madminer.analysis    INFO    Found 539913 events
# 20:06 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:06 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:06 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:06 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.         -0.11111111]
# 20:06 madminer.sampling    INFO    Starting sampling serially
# 20:06 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:06 madminer.sampling    INFO    Effective number of samples: mean 468.12226922238625, with individual thetas ranging from 468.12226922238614 to 468.12226922238614
# 20:06 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:06 madminer.analysis    INFO    Found 2 parameters
# 20:06 madminer.analysis    INFO    Did not find nuisance parameters
# 20:06 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:06 madminer.analysis    INFO    Found 3 observables
# 20:06 madminer.analysis    INFO    Found 539913 events
# 20:06 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:06 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:06 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:06 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.          0.11111111]
# 20:06 madminer.sampling    INFO    Starting sampling serially
# 20:06 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:06 madminer.sampling    INFO    Effective number of samples: mean 553.2125757107707, with individual thetas ranging from 553.2125757107709 to 553.2125757107709
# 20:06 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:06 madminer.analysis    INFO    Found 2 parameters
# 20:06 madminer.analysis    INFO    Did not find nuisance parameters
# 20:06 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:06 madminer.analysis    INFO    Found 3 observables
# 20:06 madminer.analysis    INFO    Found 539913 events
# 20:06 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:06 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:06 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:06 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:06 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.          0.33333333]
# 20:06 madminer.sampling    INFO    Starting sampling serially
# 20:06 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:06 madminer.sampling    INFO    Effective number of samples: mean 584.351030118124, with individual thetas ranging from 584.351030118124 to 584.351030118124
# 20:07 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:07 madminer.analysis    INFO    Found 2 parameters
# 20:07 madminer.analysis    INFO    Did not find nuisance parameters
# 20:07 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:07 madminer.analysis    INFO    Found 3 observables
# 20:07 madminer.analysis    INFO    Found 539913 events
# 20:07 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:07 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:07 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:07 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.          0.55555556]
# 20:07 madminer.sampling    INFO    Starting sampling serially
# 20:07 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:07 madminer.sampling    INFO    Effective number of samples: mean 542.8467263397779, with individual thetas ranging from 542.8467263397781 to 542.8467263397781
# 20:07 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:07 madminer.analysis    INFO    Found 2 parameters
# 20:07 madminer.analysis    INFO    Did not find nuisance parameters
# 20:07 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:07 madminer.analysis    INFO    Found 3 observables
# 20:07 madminer.analysis    INFO    Found 539913 events
# 20:07 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:07 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:07 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:07 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.          0.77777778]
# 20:07 madminer.sampling    INFO    Starting sampling serially
# 20:07 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:07 madminer.sampling    INFO    Effective number of samples: mean 458.921683459026, with individual thetas ranging from 458.92168345902604 to 458.92168345902604
# 20:07 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:07 madminer.analysis    INFO    Found 2 parameters
# 20:07 madminer.analysis    INFO    Did not find nuisance parameters
# 20:07 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:07 madminer.analysis    INFO    Found 3 observables
# 20:07 madminer.analysis    INFO    Found 539913 events
# 20:07 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:07 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:07 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:07 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:07 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.  1.]
# 20:07 madminer.sampling    INFO    Starting sampling serially
# 20:07 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:07 madminer.sampling    INFO    Effective number of samples: mean 371.8792740899334, with individual thetas ranging from 371.8792740899334 to 371.8792740899334
# 20:08 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:08 madminer.analysis    INFO    Found 2 parameters
# 20:08 madminer.analysis    INFO    Did not find nuisance parameters
# 20:08 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:08 madminer.analysis    INFO    Found 3 observables
# 20:08 madminer.analysis    INFO    Found 539913 events
# 20:08 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:08 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:08 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:08 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778 -1.        ]
# 20:08 madminer.sampling    INFO    Starting sampling serially
# 20:08 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:08 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.7777778 -1.       ]: (0.001666 +/- 0.000216) pb (12.960459759624012 %). Skipping these warnings in the future...
# 20:08 madminer.sampling    WARNING For this value of theta, 1 / 92601 events have negative weight and will be ignored
# 20:08 madminer.sampling    INFO    Effective number of samples: mean 208.56495852707985, with individual thetas ranging from 208.56495852707985 to 208.56495852707985
# 20:08 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:08 madminer.analysis    INFO    Found 2 parameters
# 20:08 madminer.analysis    INFO    Did not find nuisance parameters
# 20:08 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:08 madminer.analysis    INFO    Found 3 observables
# 20:08 madminer.analysis    INFO    Found 539913 events
# 20:08 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:08 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:08 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:08 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778 -0.77777778]
# 20:08 madminer.sampling    INFO    Starting sampling serially
# 20:08 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:08 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.7777778 -0.7777778]: (0.001582 +/- 0.000191) pb (12.106204929215593 %). Skipping these warnings in the future...
# 20:08 madminer.sampling    INFO    Effective number of samples: mean 267.2268218846479, with individual thetas ranging from 267.22682188464785 to 267.22682188464785
# 20:08 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:08 madminer.analysis    INFO    Found 2 parameters
# 20:08 madminer.analysis    INFO    Did not find nuisance parameters
# 20:08 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:08 madminer.analysis    INFO    Found 3 observables
# 20:08 madminer.analysis    INFO    Found 539913 events
# 20:08 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:08 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:08 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:08 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:08 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778 -0.55555556]
# 20:08 madminer.sampling    INFO    Starting sampling serially
# 20:08 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:08 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.7777778 -0.5555556]: (0.001519 +/- 0.000167) pb (10.978989174838114 %). Skipping these warnings in the future...
# 20:08 madminer.sampling    INFO    Effective number of samples: mean 356.22668848024654, with individual thetas ranging from 356.22668848024637 to 356.22668848024637
# 20:09 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:09 madminer.analysis    INFO    Found 2 parameters
# 20:09 madminer.analysis    INFO    Did not find nuisance parameters
# 20:09 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:09 madminer.analysis    INFO    Found 3 observables
# 20:09 madminer.analysis    INFO    Found 539913 events
# 20:09 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:09 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:09 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:09 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778 -0.33333333]
# 20:09 madminer.sampling    INFO    Starting sampling serially
# 20:09 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:09 madminer.sampling    INFO    Effective number of samples: mean 489.04242363560587, with individual thetas ranging from 489.042423635606 to 489.042423635606
# 20:09 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:09 madminer.analysis    INFO    Found 2 parameters
# 20:09 madminer.analysis    INFO    Did not find nuisance parameters
# 20:09 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:09 madminer.analysis    INFO    Found 3 observables
# 20:09 madminer.analysis    INFO    Found 539913 events
# 20:09 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:09 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:09 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:09 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778 -0.11111111]
# 20:09 madminer.sampling    INFO    Starting sampling serially
# 20:09 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:09 madminer.sampling    INFO    Effective number of samples: mean 665.3703988629005, with individual thetas ranging from 665.3703988629006 to 665.3703988629006
# 20:09 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:09 madminer.analysis    INFO    Found 2 parameters
# 20:09 madminer.analysis    INFO    Did not find nuisance parameters
# 20:09 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:09 madminer.analysis    INFO    Found 3 observables
# 20:09 madminer.analysis    INFO    Found 539913 events
# 20:09 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:09 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:09 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:09 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:09 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778  0.11111111]
# 20:09 madminer.sampling    INFO    Starting sampling serially
# 20:09 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:09 madminer.sampling    INFO    Effective number of samples: mean 823.3559424404409, with individual thetas ranging from 823.3559424404407 to 823.3559424404407
# 20:10 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:10 madminer.analysis    INFO    Found 2 parameters
# 20:10 madminer.analysis    INFO    Did not find nuisance parameters
# 20:10 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:10 madminer.analysis    INFO    Found 3 observables
# 20:10 madminer.analysis    INFO    Found 539913 events
# 20:10 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:10 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:10 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:10 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778  0.33333333]
# 20:10 madminer.sampling    INFO    Starting sampling serially
# 20:10 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:10 madminer.sampling    INFO    Effective number of samples: mean 838.93835804063, with individual thetas ranging from 838.9383580406295 to 838.9383580406295
# 20:10 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:10 madminer.analysis    INFO    Found 2 parameters
# 20:10 madminer.analysis    INFO    Did not find nuisance parameters
# 20:10 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:10 madminer.analysis    INFO    Found 3 observables
# 20:10 madminer.analysis    INFO    Found 539913 events
# 20:10 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:10 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:10 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:10 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778  0.55555556]
# 20:10 madminer.sampling    INFO    Starting sampling serially
# 20:10 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:10 madminer.sampling    INFO    Effective number of samples: mean 701.6773818838217, with individual thetas ranging from 701.6773818838218 to 701.6773818838218
# 20:10 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:10 madminer.analysis    INFO    Found 2 parameters
# 20:10 madminer.analysis    INFO    Did not find nuisance parameters
# 20:10 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:10 madminer.analysis    INFO    Found 3 observables
# 20:10 madminer.analysis    INFO    Found 539913 events
# 20:10 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:10 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:10 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:10 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778  0.77777778]
# 20:10 madminer.sampling    INFO    Starting sampling serially
# 20:10 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:10 madminer.sampling    INFO    Effective number of samples: mean 530.6733600357566, with individual thetas ranging from 530.6733600357567 to 530.6733600357567
# 20:10 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:10 madminer.analysis    INFO    Found 2 parameters
# 20:10 madminer.analysis    INFO    Did not find nuisance parameters
# 20:10 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:10 madminer.analysis    INFO    Found 3 observables
# 20:10 madminer.analysis    INFO    Found 539913 events
# 20:10 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:10 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:10 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:10 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:10 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778  1.        ]
# 20:10 madminer.sampling    INFO    Starting sampling serially
# 20:10 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:10 madminer.sampling    INFO    Effective number of samples: mean 395.7765171210609, with individual thetas ranging from 395.7765171210609 to 395.7765171210609
# 20:11 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:11 madminer.analysis    INFO    Found 2 parameters
# 20:11 madminer.analysis    INFO    Did not find nuisance parameters
# 20:11 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:11 madminer.analysis    INFO    Found 3 observables
# 20:11 madminer.analysis    INFO    Found 539913 events
# 20:11 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:11 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:11 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:11 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556 -1.        ]
# 20:11 madminer.sampling    INFO    Starting sampling serially
# 20:11 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:11 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.5555556 -1.       ]: (0.001522 +/- 0.000194) pb (12.74151252867661 %). Skipping these warnings in the future...
# 20:11 madminer.sampling    INFO    Effective number of samples: mean 231.96968150705297, with individual thetas ranging from 231.9696815070531 to 231.9696815070531
# 20:11 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:11 madminer.analysis    INFO    Found 2 parameters
# 20:11 madminer.analysis    INFO    Did not find nuisance parameters
# 20:11 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:11 madminer.analysis    INFO    Found 3 observables
# 20:11 madminer.analysis    INFO    Found 539913 events
# 20:11 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:11 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:11 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:11 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556 -0.77777778]
# 20:11 madminer.sampling    INFO    Starting sampling serially
# 20:11 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:11 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.5555556 -0.7777778]: (0.001438 +/- 0.000170) pb (11.795979691402767 %). Skipping these warnings in the future...
# 20:11 madminer.sampling    INFO    Effective number of samples: mean 312.1948761794793, with individual thetas ranging from 312.1948761794795 to 312.1948761794795
# 20:11 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:11 madminer.analysis    INFO    Found 2 parameters
# 20:11 madminer.analysis    INFO    Did not find nuisance parameters
# 20:11 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:11 madminer.analysis    INFO    Found 3 observables
# 20:11 madminer.analysis    INFO    Found 539913 events
# 20:11 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:11 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:11 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:11 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:11 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556 -0.55555556]
# 20:11 madminer.sampling    INFO    Starting sampling serially
# 20:11 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:11 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.5555556 -0.5555556]: (0.001375 +/- 0.000145) pb (10.542631892100937 %). Skipping these warnings in the future...
# 20:11 madminer.sampling    INFO    Effective number of samples: mean 448.92424179593206, with individual thetas ranging from 448.92424179593183 to 448.92424179593183
# 20:12 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:12 madminer.analysis    INFO    Found 2 parameters
# 20:12 madminer.analysis    INFO    Did not find nuisance parameters
# 20:12 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:12 madminer.analysis    INFO    Found 3 observables
# 20:12 madminer.analysis    INFO    Found 539913 events
# 20:12 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:12 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:12 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:12 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556 -0.33333333]
# 20:12 madminer.sampling    INFO    Starting sampling serially
# 20:12 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:12 madminer.sampling    INFO    Effective number of samples: mean 690.1180984805108, with individual thetas ranging from 690.118098480511 to 690.118098480511
# 20:12 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:12 madminer.analysis    INFO    Found 2 parameters
# 20:12 madminer.analysis    INFO    Did not find nuisance parameters
# 20:12 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:12 madminer.analysis    INFO    Found 3 observables
# 20:12 madminer.analysis    INFO    Found 539913 events
# 20:12 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:12 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:12 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:12 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556 -0.11111111]
# 20:12 madminer.sampling    INFO    Starting sampling serially
# 20:12 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:12 madminer.sampling    INFO    Effective number of samples: mean 1082.38872293492, with individual thetas ranging from 1082.38872293492 to 1082.38872293492
# 20:12 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:12 madminer.analysis    INFO    Found 2 parameters
# 20:12 madminer.analysis    INFO    Did not find nuisance parameters
# 20:12 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:12 madminer.analysis    INFO    Found 3 observables
# 20:12 madminer.analysis    INFO    Found 539913 events
# 20:12 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:12 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:12 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:12 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:12 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556  0.11111111]
# 20:12 madminer.sampling    INFO    Starting sampling serially
# 20:12 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:12 madminer.sampling    INFO    Effective number of samples: mean 1450.3259723827166, with individual thetas ranging from 1450.3259723827161 to 1450.3259723827161
# 20:13 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:13 madminer.analysis    INFO    Found 2 parameters
# 20:13 madminer.analysis    INFO    Did not find nuisance parameters
# 20:13 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:13 madminer.analysis    INFO    Found 3 observables
# 20:13 madminer.analysis    INFO    Found 539913 events
# 20:13 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:13 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:13 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:13 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556  0.33333333]
# 20:13 madminer.sampling    INFO    Starting sampling serially
# 20:13 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:13 madminer.sampling    INFO    Effective number of samples: mean 1321.0765350672666, with individual thetas ranging from 1321.0765350672666 to 1321.0765350672666
# 20:13 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:13 madminer.analysis    INFO    Found 2 parameters
# 20:13 madminer.analysis    INFO    Did not find nuisance parameters
# 20:13 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:13 madminer.analysis    INFO    Found 3 observables
# 20:13 madminer.analysis    INFO    Found 539913 events
# 20:13 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:13 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:13 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:13 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556  0.55555556]
# 20:13 madminer.sampling    INFO    Starting sampling serially
# 20:13 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:13 madminer.sampling    INFO    Effective number of samples: mean 901.4417939238613, with individual thetas ranging from 901.4417939238615 to 901.4417939238615
# 20:13 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:13 madminer.analysis    INFO    Found 2 parameters
# 20:13 madminer.analysis    INFO    Did not find nuisance parameters
# 20:13 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:13 madminer.analysis    INFO    Found 3 observables
# 20:13 madminer.analysis    INFO    Found 539913 events
# 20:13 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:13 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:13 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:13 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:13 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556  0.77777778]
# 20:13 madminer.sampling    INFO    Starting sampling serially
# 20:13 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:13 madminer.sampling    INFO    Effective number of samples: mean 586.091296042241, with individual thetas ranging from 586.0912960422409 to 586.0912960422409
# 20:14 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:14 madminer.analysis    INFO    Found 2 parameters
# 20:14 madminer.analysis    INFO    Did not find nuisance parameters
# 20:14 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:14 madminer.analysis    INFO    Found 3 observables
# 20:14 madminer.analysis    INFO    Found 539913 events
# 20:14 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:14 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:14 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:14 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556  1.        ]
# 20:14 madminer.sampling    INFO    Starting sampling serially
# 20:14 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:14 madminer.sampling    INFO    Effective number of samples: mean 401.1976606549821, with individual thetas ranging from 401.19766065498203 to 401.19766065498203
# 20:14 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:14 madminer.analysis    INFO    Found 2 parameters
# 20:14 madminer.analysis    INFO    Did not find nuisance parameters
# 20:14 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:14 madminer.analysis    INFO    Found 3 observables
# 20:14 madminer.analysis    INFO    Found 539913 events
# 20:14 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:14 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:14 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:14 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.33333333 -1.        ]
# 20:14 madminer.sampling    INFO    Starting sampling serially
# 20:14 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:14 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.33333334 -1.        ]: (0.001399 +/- 0.000172) pb (12.275970560905026 %). Skipping these warnings in the future...
# 20:14 madminer.sampling    INFO    Effective number of samples: mean 257.43676637676975, with individual thetas ranging from 257.43676637676975 to 257.43676637676975
# 20:14 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:14 madminer.analysis    INFO    Found 2 parameters
# 20:14 madminer.analysis    INFO    Did not find nuisance parameters
# 20:14 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:14 madminer.analysis    INFO    Found 3 observables
# 20:14 madminer.analysis    INFO    Found 539913 events
# 20:14 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:14 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:14 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:14 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.33333333 -0.77777778]
# 20:14 madminer.sampling    INFO    Starting sampling serially
# 20:14 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:14 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.33333334 -0.7777778 ]: (0.001315 +/- 0.000147) pb (11.217567874589868 %). Skipping these warnings in the future...
# 20:14 madminer.sampling    INFO    Effective number of samples: mean 366.20117197018504, with individual thetas ranging from 366.20117197018504 to 366.20117197018504
# 20:14 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:14 madminer.analysis    INFO    Found 2 parameters
# 20:14 madminer.analysis    INFO    Did not find nuisance parameters
# 20:14 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:14 madminer.analysis    INFO    Found 3 observables
# 20:14 madminer.analysis    INFO    Found 539913 events
# 20:14 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:14 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:14 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:14 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:14 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.33333333 -0.55555556]
# ...
# 20:32 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:32 madminer.analysis    INFO    Found 3 observables
# 20:32 madminer.analysis    INFO    Found 539913 events
# 20:32 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:32 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:32 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:32 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:32 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:32 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:32 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:32 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [0.77777778 1.        ]
# 20:32 madminer.sampling    INFO    Starting sampling serially
# 20:32 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:32 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [0.7777778 1.       ]: (0.001082 +/- 0.000143) pb (13.192011497762348 %). Skipping these warnings in the future...
# 20:32 madminer.sampling    INFO    Effective number of samples: mean 144.01774847774433, with individual thetas ranging from 144.01774847774428 to 144.01774847774428
# 20:33 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:33 madminer.analysis    INFO    Found 2 parameters
# 20:33 madminer.analysis    INFO    Did not find nuisance parameters
# 20:33 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:33 madminer.analysis    INFO    Found 3 observables
# 20:33 madminer.analysis    INFO    Found 539913 events
# 20:33 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:33 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:33 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:33 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [ 1. -1.]
# 20:33 madminer.sampling    INFO    Starting sampling serially
# 20:33 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:33 madminer.sampling    INFO    Effective number of samples: mean 221.52935605342552, with individual thetas ranging from 221.5293560534255 to 221.5293560534255
# 20:33 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:33 madminer.analysis    INFO    Found 2 parameters
# 20:33 madminer.analysis    INFO    Did not find nuisance parameters
# 20:33 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:33 madminer.analysis    INFO    Found 3 observables
# 20:33 madminer.analysis    INFO    Found 539913 events
# 20:33 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:33 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:33 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:33 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [ 1.         -0.77777778]
# 20:33 madminer.sampling    INFO    Starting sampling serially
# 20:33 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:33 madminer.sampling    INFO    Effective number of samples: mean 268.89997991252, with individual thetas ranging from 268.89997991252005 to 268.89997991252005
# 20:33 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:33 madminer.analysis    INFO    Found 2 parameters
# 20:33 madminer.analysis    INFO    Did not find nuisance parameters
# 20:33 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:33 madminer.analysis    INFO    Found 3 observables
# 20:33 madminer.analysis    INFO    Found 539913 events
# 20:33 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:33 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:33 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:33 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:33 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [ 1.         -0.55555556]
# 20:33 madminer.sampling    INFO    Starting sampling serially
# 20:33 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:33 madminer.sampling    INFO    Effective number of samples: mean 316.7951624145367, with individual thetas ranging from 316.79516241453666 to 316.79516241453666
# 20:34 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:34 madminer.analysis    INFO    Found 2 parameters
# 20:34 madminer.analysis    INFO    Did not find nuisance parameters
# 20:34 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:34 madminer.analysis    INFO    Found 3 observables
# 20:34 madminer.analysis    INFO    Found 539913 events
# 20:34 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:34 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:34 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:34 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [ 1.         -0.33333333]
# 20:34 madminer.sampling    INFO    Starting sampling serially
# 20:34 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:34 madminer.sampling    INFO    Effective number of samples: mean 342.86293366706417, with individual thetas ranging from 342.8629336670642 to 342.8629336670642
# 20:34 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:34 madminer.analysis    INFO    Found 2 parameters
# 20:34 madminer.analysis    INFO    Did not find nuisance parameters
# 20:34 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:34 madminer.analysis    INFO    Found 3 observables
# 20:34 madminer.analysis    INFO    Found 539913 events
# 20:34 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:34 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:34 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:34 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [ 1.         -0.11111111]
# 20:34 madminer.sampling    INFO    Starting sampling serially
# 20:34 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:34 madminer.sampling    INFO    Effective number of samples: mean 326.48434394521115, with individual thetas ranging from 326.48434394521115 to 326.48434394521115
# 20:34 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:34 madminer.analysis    INFO    Found 2 parameters
# 20:34 madminer.analysis    INFO    Did not find nuisance parameters
# 20:34 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:34 madminer.analysis    INFO    Found 3 observables
# 20:34 madminer.analysis    INFO    Found 539913 events
# 20:34 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:34 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:34 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:34 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:34 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [1.         0.11111111]
# 20:34 madminer.sampling    INFO    Starting sampling serially
# 20:34 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:34 madminer.sampling    INFO    Effective number of samples: mean 276.78864702539886, with individual thetas ranging from 276.7886470253988 to 276.7886470253988
# 20:35 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:35 madminer.analysis    INFO    Found 2 parameters
# 20:35 madminer.analysis    INFO    Did not find nuisance parameters
# 20:35 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:35 madminer.analysis    INFO    Found 3 observables
# 20:35 madminer.analysis    INFO    Found 539913 events
# 20:35 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:35 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:35 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:35 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [1.         0.33333333]
# 20:35 madminer.sampling    INFO    Starting sampling serially
# 20:35 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:35 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [1.         0.33333334]: (0.000890 +/- 0.000090) pb (10.091902214206307 %). Skipping these warnings in the future...
# 20:35 madminer.sampling    INFO    Effective number of samples: mean 220.8791785062685, with individual thetas ranging from 220.8791785062684 to 220.8791785062684
# 20:35 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:35 madminer.analysis    INFO    Found 2 parameters
# 20:35 madminer.analysis    INFO    Did not find nuisance parameters
# 20:35 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:35 madminer.analysis    INFO    Found 3 observables
# 20:35 madminer.analysis    INFO    Found 539913 events
# 20:35 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:35 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:35 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:35 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [1.         0.55555556]
# 20:35 madminer.sampling    INFO    Starting sampling serially
# 20:35 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:35 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [1.        0.5555556]: (0.000932 +/- 0.000116) pb (12.422607408687673 %). Skipping these warnings in the future...
# 20:35 madminer.sampling    INFO    Effective number of samples: mean 174.82970335818302, with individual thetas ranging from 174.82970335818302 to 174.82970335818302
# 20:35 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:35 madminer.analysis    INFO    Found 2 parameters
# 20:35 madminer.analysis    INFO    Did not find nuisance parameters
# 20:35 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:35 madminer.analysis    INFO    Found 3 observables
# 20:35 madminer.analysis    INFO    Found 539913 events
# 20:35 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:35 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:35 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:35 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:35 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [1.         0.77777778]
# 20:35 madminer.sampling    INFO    Starting sampling serially
# 20:35 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:35 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [1.        0.7777778]: (0.000995 +/- 0.000141) pb (14.147458776395247 %). Skipping these warnings in the future...
# 20:35 madminer.sampling    INFO    Effective number of samples: mean 141.2520133803712, with individual thetas ranging from 141.25201338037127 to 141.25201338037127
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [1. 1.]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [1. 1.]: (0.001079 +/- 0.000165) pb (15.312766387617673 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 117.67859391144633, with individual thetas ranging from 117.67859391144634 to 117.67859391144634

# %% [markdown]
# ### c) Histogram

# %%
start_time = time.time()
nll_hist = histolikelihood.create_expected_negative_log_likelihood(
    n_asimov=n_asimov,
    include_xsec=False,
    luminosity=lumi,
    theta_true=np.array([0, 0]),
    nu_true=None,
    observables=["pt_j1"],
    hist_bins=[[20, 100, 200, 300, 400, 500]],
    mode="sampled",
    n_histo_toys=n_histo_toys,
)

theta_grid, p_values_expected, best_fit_expected, llr = project_log_likelihood(
    negative_log_likelihood=nll_hist,
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
)
duration = time.time() - start_time

p_values["LHS: Histo"] = p_values_expected
mle["LHS: Histo"] = best_fit_expected
durations["LHS: Histo"] = duration
# Out:
# 20:36 madminer.likelihood  INFO    Setting up standard summary statistics
# 20:36 madminer.likelihood  INFO    Setting up binning
# 20:36 madminer.likelihood  INFO    Use binning: [[20, 100, 200, 300, 400, 500]]
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1. -1.]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-1. -1.]: (0.001829 +/- 0.000238) pb (12.988401897209778 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 188.4528978580944, with individual thetas ranging from 188.45289785809442 to 188.45289785809442
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.         -0.77777778]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-1.        -0.7777778]: (0.001745 +/- 0.000213) pb (12.20963321703818 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 231.86820313505046, with individual thetas ranging from 231.86820313505046 to 231.86820313505046
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.         -0.55555556]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-1.        -0.5555556]: (0.001682 +/- 0.000188) pb (11.190468219271528 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 292.10694400103097, with individual thetas ranging from 292.10694400103085 to 292.10694400103085
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.         -0.33333333]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 372.52573958188566, with individual thetas ranging from 372.52573958188566 to 372.52573958188566
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.         -0.11111111]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 468.12226922238625, with individual thetas ranging from 468.12226922238614 to 468.12226922238614
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.          0.11111111]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 553.2125757107707, with individual thetas ranging from 553.2125757107709 to 553.2125757107709
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.          0.33333333]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 584.351030118124, with individual thetas ranging from 584.351030118124 to 584.351030118124
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.          0.55555556]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 542.8467263397779, with individual thetas ranging from 542.8467263397781 to 542.8467263397781
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.          0.77777778]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 458.921683459026, with individual thetas ranging from 458.92168345902604 to 458.92168345902604
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-1.  1.]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 371.8792740899334, with individual thetas ranging from 371.8792740899334 to 371.8792740899334
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778 -1.        ]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.7777778 -1.       ]: (0.001666 +/- 0.000216) pb (12.960459759624012 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    WARNING For this value of theta, 1 / 92601 events have negative weight and will be ignored
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 208.56495852707985, with individual thetas ranging from 208.56495852707985 to 208.56495852707985
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778 -0.77777778]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.7777778 -0.7777778]: (0.001582 +/- 0.000191) pb (12.106204929215593 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 267.2268218846479, with individual thetas ranging from 267.22682188464785 to 267.22682188464785
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778 -0.55555556]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.7777778 -0.5555556]: (0.001519 +/- 0.000167) pb (10.978989174838114 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 356.22668848024654, with individual thetas ranging from 356.22668848024637 to 356.22668848024637
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778 -0.33333333]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 489.04242363560587, with individual thetas ranging from 489.042423635606 to 489.042423635606
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778 -0.11111111]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 665.3703988629005, with individual thetas ranging from 665.3703988629006 to 665.3703988629006
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778  0.11111111]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 823.3559424404409, with individual thetas ranging from 823.3559424404407 to 823.3559424404407
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778  0.33333333]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 838.93835804063, with individual thetas ranging from 838.9383580406295 to 838.9383580406295
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778  0.55555556]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 701.6773818838217, with individual thetas ranging from 701.6773818838218 to 701.6773818838218
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778  0.77777778]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 530.6733600357566, with individual thetas ranging from 530.6733600357567 to 530.6733600357567
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.77777778  1.        ]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 395.7765171210609, with individual thetas ranging from 395.7765171210609 to 395.7765171210609
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556 -1.        ]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.5555556 -1.       ]: (0.001522 +/- 0.000194) pb (12.74151252867661 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 231.96968150705297, with individual thetas ranging from 231.9696815070531 to 231.9696815070531
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556 -0.77777778]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.5555556 -0.7777778]: (0.001438 +/- 0.000170) pb (11.795979691402767 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 312.1948761794793, with individual thetas ranging from 312.1948761794795 to 312.1948761794795
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556 -0.55555556]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.5555556 -0.5555556]: (0.001375 +/- 0.000145) pb (10.542631892100937 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 448.92424179593206, with individual thetas ranging from 448.92424179593183 to 448.92424179593183
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556 -0.33333333]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 690.1180984805108, with individual thetas ranging from 690.118098480511 to 690.118098480511
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556 -0.11111111]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 1082.38872293492, with individual thetas ranging from 1082.38872293492 to 1082.38872293492
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556  0.11111111]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 1450.3259723827166, with individual thetas ranging from 1450.3259723827161 to 1450.3259723827161
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556  0.33333333]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 1321.0765350672666, with individual thetas ranging from 1321.0765350672666 to 1321.0765350672666
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556  0.55555556]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 901.4417939238613, with individual thetas ranging from 901.4417939238615 to 901.4417939238615
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556  0.77777778]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 586.091296042241, with individual thetas ranging from 586.0912960422409 to 586.0912960422409
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.55555556  1.        ]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 401.1976606549821, with individual thetas ranging from 401.19766065498203 to 401.19766065498203
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.33333333 -1.        ]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.33333334 -1.        ]: (0.001399 +/- 0.000172) pb (12.275970560905026 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 257.43676637676975, with individual thetas ranging from 257.43676637676975 to 257.43676637676975
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.33333333 -0.77777778]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-0.33333334 -0.7777778 ]: (0.001315 +/- 0.000147) pb (11.217567874589868 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 366.20117197018504, with individual thetas ranging from 366.20117197018504 to 366.20117197018504
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [-0.33333333 -0.55555556]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# ...
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [0.77777778 1.        ]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [0.7777778 1.       ]: (0.001082 +/- 0.000143) pb (13.192011497762348 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 144.01774847774433, with individual thetas ranging from 144.01774847774428 to 144.01774847774428
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [ 1. -1.]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 221.52935605342552, with individual thetas ranging from 221.5293560534255 to 221.5293560534255
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [ 1.         -0.77777778]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 268.89997991252, with individual thetas ranging from 268.89997991252005 to 268.89997991252005
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [ 1.         -0.55555556]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 316.7951624145367, with individual thetas ranging from 316.79516241453666 to 316.79516241453666
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [ 1.         -0.33333333]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 342.86293366706417, with individual thetas ranging from 342.8629336670642 to 342.8629336670642
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [ 1.         -0.11111111]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 326.48434394521115, with individual thetas ranging from 326.48434394521115 to 326.48434394521115
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [1.         0.11111111]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 276.78864702539886, with individual thetas ranging from 276.7886470253988 to 276.7886470253988
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [1.         0.33333333]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [1.         0.33333334]: (0.000890 +/- 0.000090) pb (10.091902214206307 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 220.8791785062685, with individual thetas ranging from 220.8791785062684 to 220.8791785062684
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [1.         0.55555556]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [1.        0.5555556]: (0.000932 +/- 0.000116) pb (12.422607408687673 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 174.82970335818302, with individual thetas ranging from 174.82970335818302 to 174.82970335818302
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [1.         0.77777778]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [1.        0.7777778]: (0.000995 +/- 0.000141) pb (14.147458776395247 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 141.2520133803712, with individual thetas ranging from 141.25201338037127 to 141.25201338037127
# 20:36 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 20:36 madminer.analysis    INFO    Found 2 parameters
# 20:36 madminer.analysis    INFO    Did not find nuisance parameters
# 20:36 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 20:36 madminer.analysis    INFO    Found 3 observables
# 20:36 madminer.analysis    INFO    Found 539913 events
# 20:36 madminer.analysis    INFO      499913 signal events sampled from benchmark sm
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 20:36 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_ww
# 20:36 madminer.analysis    INFO    Found morphing setup with 6 components
# 20:36 madminer.analysis    INFO    Did not find nuisance morphing setup
# 20:36 madminer.sampling    INFO    Extracting plain training sample. Sampling according to [1. 1.]
# 20:36 madminer.sampling    INFO    Starting sampling serially
# 20:36 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 20:36 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [1. 1.]: (0.001079 +/- 0.000165) pb (15.312766387617673 %). Skipping these warnings in the future...
# 20:36 madminer.sampling    INFO    Effective number of samples: mean 117.67859391144633, with individual thetas ranging from 117.67859391144634 to 117.67859391144634

# %% [markdown]
# ### d) Rate

# %%
start_time = time.time()
nll_rate = histolikelihood.create_expected_negative_log_likelihood(
    n_asimov=n_asimov,
    include_xsec=True,
    luminosity=lumi,
    theta_true=np.array([0, 0]),
    nu_true=None,
    observables=None,
    mode="sampled",
)

theta_grid, p_values_expected, best_fit_expected, llr = project_log_likelihood(
    negative_log_likelihood=nll_rate,
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
)
duration = time.time() - start_time

p_values["LHS: Rate"] = p_values_expected
mle["LHS: Rate"] = best_fit_expected
durations["LHS: Rate"] = duration
# Out:
# 20:36 madminer.likelihood  INFO    No observables and scores provided. Calculate LLR due to rate and set include_xsec=True.
# 20:36 madminer.likelihood  INFO    Setting up standard summary statistics
# 20:36 madminer.likelihood  INFO    Setting up binning
# 20:36 madminer.likelihood  INFO    Use binning: None

# %% [markdown]
# ## 3. Using Likelihood class - Unweighted

# %% [markdown]
# How let's use the `mode=weighted` mode when calculating the likelihood function. This means that we first create a set of unweighted events. Later, these events are used to calculate the cross section and create the histograms for each parameter point. This setup is expected to be faster.

# %% [markdown]
# ### a) ALICES

# %%
start_time = time.time()
nll_alices = neurallikelihood.create_expected_negative_log_likelihood(
    n_asimov=n_asimov,
    include_xsec=False,
    luminosity=lumi,
    theta_true=np.array([0, 0]),
    nu_true=None,
    model_file="models/alices",
    mode="weighted",
    n_weighted=n_histo_toys,
)

theta_grid, p_values_expected, best_fit_expected, llr = project_log_likelihood(
    negative_log_likelihood=nll_alices,
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
)
duration = time.time() - start_time

p_values["LHW: ALICES"] = p_values_expected
mle["LHW: ALICES"] = best_fit_expected
durations["LHW: ALICES"] = duration
# Out:
# 20:36 madminer.ml          INFO    Loading model from models/alices

# %% [markdown]
# ### b) SALLY

# %%
start_time = time.time()
nll_sally = histolikelihood.create_expected_negative_log_likelihood(
    n_asimov=n_asimov,
    include_xsec=False,
    luminosity=lumi,
    theta_true=np.array([0, 0]),
    nu_true=None,
    score_components=[0, 1],
    model_file="models/sally",
    hist_bins=[5, 5],
    mode="weighted",
    n_histo_toys=n_histo_toys,
)

theta_grid, p_values_expected, best_fit_expected, llr = project_log_likelihood(
    negative_log_likelihood=nll_sally,
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
)
duration = time.time() - start_time

p_values["LHW: SALLY"] = p_values_expected
mle["LHW: SALLY"] = best_fit_expected
durations["LHW: SALLY"] = duration
# Out:
# 20:37 madminer.ml          INFO    Loading model from models/sally
# 20:37 madminer.likelihood  INFO    Setting up standard summary statistics
# 20:37 madminer.likelihood  INFO    Getting weighted data
# 20:37 madminer.likelihood  INFO    Setting up binning
# 20:37 madminer.likelihood  INFO    Use binning: [array([-7.31596707, -0.14345846,  0.10058699,  0.22946604,  0.31041272,
#         0.37705326]), array([-3.32069593, -0.34406366, -0.10538475,  0.11455534,  0.34237415,
#         3.83437803])]

# %% [markdown]
# ### c) Histogram

# %%
start_time = time.time()
nll_hist = histolikelihood.create_expected_negative_log_likelihood(
    n_asimov=n_asimov,
    include_xsec=False,
    luminosity=lumi,
    theta_true=np.array([0, 0]),
    nu_true=None,
    observables=["pt_j1"],
    hist_bins=[[20, 100, 200, 300, 400, 500]],
    mode="weighted",
    n_histo_toys=n_histo_toys,
)

theta_grid, p_values_expected, best_fit_expected, llr = project_log_likelihood(
    negative_log_likelihood=nll_hist,
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
)
duration = time.time() - start_time

p_values["LHW: Histo"] = p_values_expected
mle["LHW: Histo"] = best_fit_expected
durations["LHW: Histo"] = duration
# Out:
# 20:37 madminer.likelihood  INFO    Setting up standard summary statistics
# 20:37 madminer.likelihood  INFO    Getting weighted data
# 20:37 madminer.likelihood  INFO    Setting up binning
# 20:37 madminer.likelihood  INFO    Use binning: [[20, 100, 200, 300, 400, 500]]

# %% [markdown]
# ### d) Rate

# %%
start_time = time.time()
nll_rate = histolikelihood.create_expected_negative_log_likelihood(
    n_asimov=n_asimov,
    include_xsec=True,
    luminosity=lumi,
    theta_true=np.array([0, 0]),
    nu_true=None,
    observables=None,
    mode="weighted",
    n_histo_toys=n_histo_toys,
)

theta_grid, p_values_expected, best_fit_expected, llr = project_log_likelihood(
    negative_log_likelihood=nll_rate,
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
)
duration = time.time() - start_time

p_values["LHW: Rate"] = p_values_expected
mle["LHW: Rate"] = best_fit_expected
durations["LHW: Rate"] = duration
# Out:
# 20:37 madminer.likelihood  INFO    No observables and scores provided. Calculate LLR due to rate and set include_xsec=True.
# 20:37 madminer.likelihood  INFO    Setting up standard summary statistics
# 20:37 madminer.likelihood  INFO    Getting weighted data
# 20:37 madminer.likelihood  INFO    Setting up binning
# 20:37 madminer.likelihood  INFO    Use binning: None

# %% [markdown]
# ## 4. Using Likelihood class - Histograms

# %% [markdown]
# Finally, we can use the `mode=histo` mode when calculating the likelihood function. This options first creates histograms for each morphing benchmarks, which are later morphed to create the histograms for each parameter point. This setup is expected to be the fastest, especially when there are a large number of grid points at which the likelihood has to be evaulated.
#
# **Note:** Currently, this mode doesn't support nuissance parameter.

# %% [markdown]
# ### a) SALLY

# %%
start_time = time.time()
nll_sally = histolikelihood.create_expected_negative_log_likelihood(
    n_asimov=n_asimov,
    include_xsec=True,
    luminosity=lumi,
    theta_true=np.array([0, 0]),
    nu_true=None,
    score_components=[0, 1],
    model_file="models/sally",
    hist_bins=[5, 5],
    mode="histo",
    n_histo_toys=n_histo_toys,
)

theta_grid, p_values_expected, best_fit_expected, llr = project_log_likelihood(
    negative_log_likelihood=nll_sally,
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
)
duration = time.time() - start_time

p_values["LHH: SALLY"] = p_values_expected
mle["LHH: SALLY"] = best_fit_expected
durations["LHH: SALLY"] = duration
# Out:
# 20:37 madminer.ml          INFO    Loading model from models/sally
# 20:37 madminer.likelihood  INFO    Setting up standard summary statistics
# 20:37 madminer.likelihood  INFO    Getting weighted data
# 20:37 madminer.likelihood  INFO    Setting up binning
# 20:37 madminer.likelihood  INFO    Use binning: [array([-7.73806016, -0.14142476,  0.10339331,  0.22725957,  0.30809923,
#         0.37746276]), array([-3.38298333, -0.34644834, -0.10689301,  0.11544048,  0.34967544,
#         3.79733702])]

# %% [markdown]
# ### b) Histogram

# %%
start_time = time.time()
nll_hist = histolikelihood.create_expected_negative_log_likelihood(
    n_asimov=n_asimov,
    include_xsec=True,
    luminosity=lumi,
    theta_true=np.array([0, 0]),
    nu_true=None,
    observables=["pt_j1"],
    hist_bins=[[20, 100, 200, 300, 400, 500]],
    mode="histo",
    n_histo_toys=n_histo_toys,
)

theta_grid, p_values_expected, best_fit_expected, llr = project_log_likelihood(
    negative_log_likelihood=nll_hist,
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
)
duration = time.time() - start_time

p_values["LHH: Histo"] = p_values_expected
mle["LHH: Histo"] = best_fit_expected
durations["LHH: Histo"] = duration
# Out:
# 20:37 madminer.likelihood  INFO    Setting up standard summary statistics
# 20:37 madminer.likelihood  INFO    Getting weighted data
# 20:37 madminer.likelihood  INFO    Setting up binning
# 20:37 madminer.likelihood  INFO    Use binning: [[20, 100, 200, 300, 400, 500]]

# %% [markdown]
# ### c) Rate

# %%
start_time = time.time()
nll_rate = histolikelihood.create_expected_negative_log_likelihood(
    n_asimov=n_asimov,
    include_xsec=True,
    luminosity=lumi,
    theta_true=np.array([0, 0]),
    nu_true=None,
    observables=None,
    mode="histo",
    n_histo_toys=n_histo_toys,
)

theta_grid, p_values_expected, best_fit_expected, llr = project_log_likelihood(
    negative_log_likelihood=nll_rate,
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
)
duration = time.time() - start_time

p_values["LHH: Rate"] = p_values_expected
mle["LHH: Rate"] = best_fit_expected
durations["LHH: Rate"] = duration
# Out:
# 20:37 madminer.likelihood  INFO    No observables and scores provided. Calculate LLR due to rate and set include_xsec=True.
# 20:37 madminer.likelihood  INFO    Setting up standard summary statistics
# 20:37 madminer.likelihood  INFO    Getting weighted data
# 20:37 madminer.likelihood  INFO    Setting up binning
# 20:37 madminer.likelihood  INFO    Use binning: None

# %% [markdown]
# ## 5. Plot Results

# %% [markdown]
# Let's plot the results:

# %%
plot_pvalue_limits(
    p_values=p_values,
    best_fits=mle,
    labels=["AL: ALICES", "LHS: ALICES", "LHW: ALICES"],
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
    single_plot=False,
)

plot_pvalue_limits(
    p_values=p_values,
    best_fits=mle,
    labels=["AL: SALLY", "LHS: SALLY", "LHW: SALLY", "LHH: SALLY"],
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
    single_plot=False,
)

plot_pvalue_limits(
    p_values=p_values,
    best_fits=mle,
    labels=["AL: Histo", "LHS: Histo", "LHW: Histo", "LHH: Histo"],
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
    single_plot=False,
)

plot_pvalue_limits(
    p_values=p_values,
    best_fits=mle,
    labels=["AL: Rate", "LHS: Rate", "LHW: Rate", "LHH: Rate"],
    grid_ranges=grid_ranges,
    grid_resolutions=grid_resolutions,
    single_plot=False,
)

# %% [markdown]
# We can also look at the computation time:

# %%
labels = [
    "AL: ALICES",
    "AL: SALLY",
    "AL: Histo",
    "AL: Rate",
    "LHS: ALICES",
    "LHS: SALLY",
    "LHS: Histo",
    "LHS: Rate",
    "LHW: ALICES",
    "LHW: SALLY",
    "LHW: Histo",
    "LHW: Rate",
    "LHH: SALLY",
    "LHH: Histo",
    "LHH: Rate",
]
colors = ["C0", "C1", "C2", "C3", "C0", "C1", "C2", "C3", "C0", "C1", "C2", "C3", "C1", "C2", "C3"]
times = [durations[str(label)] for label in labels]
indices = [i for i in range(len(labels))]

fig, ax = plt.subplots(figsize=(1.5 * len(labels), 5))
plt.bar(indices, times, color=colors)
plt.xticks(indices, labels)
plt.yscale("log")
plt.ylabel("Computation Time [sec]")
plt.show()

# %%
# np.save("limits/c1.npy",[p_values,mle,durations])

# %% [markdown]
# ## 6. Profile over one parameter

# %% [markdown]
# Let's look more closely rate. At first we calculate the expected p-value in a grid.

# %%
grid_ranges_rate = [(-1, 3.0), (-1, 1.0)]
grid_resolutions_rate = [20, 10]
theta_grid_rate, p_values_expected_rate, mle_rate, _ = project_log_likelihood(
    negative_log_likelihood=nll_rate,
    grid_ranges=grid_ranges_rate,
    grid_resolutions=grid_resolutions_rate,
)

# %% [markdown]
# We can also profile over a parameter using the function `profile_log_likelihood` to profile over the rate only likelihood function.

# %%
theta_grid_proj, p_values_expected_proj, best_fit_expected_proj, llr_proj = project_log_likelihood(
    negative_log_likelihood=nll_rate,
    grid_ranges=[(-1, 3)],
    grid_resolutions=[50],
    remaining_components=[0],
)
theta_grid_prof, p_values_expected_prof, best_fit_expected_prof, llr_prof = profile_log_likelihood(
    negative_log_likelihood=nll_rate,
    grid_ranges=[(-1, 3)],
    grid_resolutions=[50],
    remaining_components=[0],
    theta_start=np.array([0, 0]),
)
# Out:
# 20:37 madminer.likelihood  INFO    Processed 1.0 % of parameter points in 0.4 seconds.
# 20:37 madminer.likelihood  INFO    Processed 2.0 % of parameter points in 0.7 seconds.
# 20:37 madminer.likelihood  INFO    Processed 4.0 % of parameter points in 0.9 seconds.
# 20:37 madminer.likelihood  INFO    Processed 6.0 % of parameter points in 1.5 seconds.
# 20:38 madminer.likelihood  INFO    Processed 8.0 % of parameter points in 1.8 seconds.
# 20:38 madminer.likelihood  INFO    Processed 20.0 % of parameter points in 3.9 seconds.
# 20:38 madminer.likelihood  INFO    Processed 30.0 % of parameter points in 5.9 seconds.
# 20:38 madminer.likelihood  INFO    Processed 40.0 % of parameter points in 8.5 seconds.
# 20:38 madminer.likelihood  INFO    Processed 50.0 % of parameter points in 11.0 seconds.
# 20:38 madminer.likelihood  INFO    Processed 60.0 % of parameter points in 13.2 seconds.
# 20:38 madminer.likelihood  INFO    Processed 70.0 % of parameter points in 15.3 seconds.
# 20:38 madminer.likelihood  INFO    Processed 80.0 % of parameter points in 16.5 seconds.
# 20:38 madminer.likelihood  INFO    Processed 90.0 % of parameter points in 18.6 seconds.

# %% [markdown]
# Let's now plot both the 2-dimensional and 1-dimensional result.

# %%
plot_pvalue_limits(
    p_values=np.array([p_values_expected_rate]),
    best_fits=np.array([mle_rate]),
    labels=["Rate"],
    grid_ranges=grid_ranges_rate,
    grid_resolutions=grid_resolutions_rate,
    show_index=0,
)

fig = plt.figure(figsize=(5, 5))
plt.scatter(theta_grid_prof, p_values_expected_prof, label="profiled")
plt.scatter(theta_grid_proj, p_values_expected_proj, label="projected", marker="*")
plt.xlabel(r"$\theta_0$")
plt.ylabel("p-value")
plt.yscale("log")
plt.ylim(0.001, 1.1)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that 2-dimensional has the shape of a donut - it has a blind direction where the rate is unchanged. If we project the likelihood in one dimension (so set the other parameter to zero) we obtain a double peak structue. However, if we properly profile of the other component, we get a plateau. This reflects that in the platau region we can find a value of $\theta$ that leads to the same rate and hence same likelihood as the SM reference point.
