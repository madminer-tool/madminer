# %% [markdown]
# # MadMiner particle physics tutorial
#
# # Part 3a: Training a likelihood ratio estimator
#
# Johann Brehmer, Felix Kling, Irina Espejo, and Kyle Cranmer 2018-2019

# %% [markdown]
# In part 3a of this tutorial we will finally train a neural network to estimate likelihood ratios. We assume that you have run part 1 and 2a of this tutorial. If, instead of 2a, you have run part 2b, you just have to load a different filename later.

# %% [markdown]
# ## Preparations

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import logging
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

from madminer.sampling import SampleAugmenter
from madminer import sampling
from madminer.ml import ParameterizedRatioEstimator

# %%
# MadMiner output
logging.basicConfig(
    format='%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s',
    datefmt='%H:%M',
    level=logging.DEBUG
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. Make (unweighted) training and test samples with augmented data

# %% [markdown]
# At this point, we have all the information we need from the simulations. But the data is not quite ready to be used for machine learning. The `madminer.sampling` class `SampleAugmenter` will take care of the remaining book-keeping steps before we can train our estimators:
#
# First, it unweights the samples, i.e. for a given parameter vector `theta` (or a distribution `p(theta)`) it picks events `x` such that their distribution follows `p(x|theta)`. The selected samples will all come from the event file we have so far, but their frequency is changed -- some events will appear multiple times, some will disappear.
#
# Second, `SampleAugmenter` calculates all the augmented data ("gold") that is the key to our new inference methods. Depending on the specific technique, these are the joint likelihood ratio and / or the joint score. It saves all these pieces of information for the selected events in a set of numpy files that can easily be used in any machine learning framework.

# %%
sampler = SampleAugmenter('data/lhe_data_shuffled.h5')
# sampler = SampleAugmenter('data/delphes_data_shuffled.h5')
# Out:
# 14:40 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 14:40 madminer.analysis    INFO    Found 2 parameters
# 14:40 madminer.analysis    DEBUG      CWL2 (LHA: dim6 2, maximal power in squared ME: (2,), range: (-20.0, 20.0))
# 14:40 madminer.analysis    DEBUG      CPWL2 (LHA: dim6 5, maximal power in squared ME: (2,), range: (-20.0, 20.0))
# 14:40 madminer.analysis    INFO    Did not find nuisance parameters
# 14:40 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 14:40 madminer.analysis    DEBUG      sm: CWL2 = 0.00e+00, CPWL2 = 0.00e+00
# 14:40 madminer.analysis    DEBUG      w: CWL2 = 15.00, CPWL2 = 0.00e+00
# 14:40 madminer.analysis    DEBUG      neg_w: CWL2 = -1.50e+01, CPWL2 = 0.00e+00
# 14:40 madminer.analysis    DEBUG      ww: CWL2 = 0.00e+00, CPWL2 = 15.00
# 14:40 madminer.analysis    DEBUG      neg_ww: CWL2 = 0.00e+00, CPWL2 = -1.50e+01
# 14:40 madminer.analysis    DEBUG      morphing_basis_vector_5: CWL2 = -1.37e+01, CPWL2 = 19.49
# 14:40 madminer.analysis    INFO    Found 3 observables
# 14:40 madminer.analysis    DEBUG      0 pt_j1
# 14:40 madminer.analysis    DEBUG      1 delta_phi_jj
# 14:40 madminer.analysis    DEBUG      2 met
# 14:40 madminer.analysis    INFO    Found 15030 events
# 14:40 madminer.analysis    INFO      10041 generated from sm
# 14:40 madminer.analysis    INFO      1023 generated from w
# 14:40 madminer.analysis    INFO      1127 generated from neg_w
# 14:40 madminer.analysis    INFO      1450 generated from ww
# 14:40 madminer.analysis    INFO      1389 generated from neg_ww
# 14:40 madminer.analysis    INFO    Found morphing setup with 6 components

# %% [markdown]
# The `SampleAugmenter` class defines five different high-level functions to generate train or test samples:
# - `sample_train_plain()`, which only saves observations x, for instance for histograms or ABC;
# - `sample_train_local()` for methods like SALLY and SALLINO, which will be demonstrated in the second part of the tutorial;
# - `sample_train_density()` for neural density estimation techniques like MAF or SCANDAL;
# - `sample_train_ratio()` for techniques like CARL, ROLR, CASCAL, and RASCAL, when only theta0 is parameterized;
# - `sample_train_more_ratios()` for the same techniques, but with both theta0 and theta1 parameterized;
# - `sample_test()` for the evaluation of any method.
#
# For the arguments `theta`, `theta0`, or `theta1`, you can (and should!) use the helper functions `benchmark()`, `benchmarks()`, `morphing_point()`, `morphing_points()`, and `random_morphing_points()`, all defined in the `madminer.sampling` module.
#
# Here we'll train a likelihood ratio estimator with the ALICES method, so we focus on the `extract_samples_train_ratio()` function. We'll sample the numerator hypothesis in the likelihood ratio with 1000 points drawn from a Gaussian prior, and fix the denominator hypothesis to the SM.
#
# Note the keyword `sample_only_from_closest_benchmark=True`, which makes sure that for each parameter point we only use the events that were originally (in MG) generated from the closest benchmark. This reduces the statistical fluctuations in the outcome quite a bit.

# %%
x, theta0, theta1, y, r_xz, t_xz, n_effective = sampler.sample_train_ratio(
    theta0=sampling.random_morphing_points(20, [('gaussian', 0., 15.), ('gaussian', 0., 15.)]),
    theta1=sampling.benchmark('sm'),
    n_samples=100,
    folder='./data/samples',
    filename='train_ratio',
    sample_only_from_closest_benchmark=True,
    return_individual_n_effective=True,
)
# Out:
# 14:40 madminer.sampling    INFO    Extracting training sample for ratio-based methods. Numerator hypothesis: 20 random morphing points, drawn from the following priors:%s, denominator hypothesis: sm
# 14:40 madminer.sampling    DEBUG   Starting sample extraction
# 14:40 madminer.sampling    INFO    Starting sampling serially
# 14:40 madminer.sampling    DEBUG   Will print training progress every 1 sets
# 14:40 madminer.sampling    INFO    Sampling from parameter point 1 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-26.09794673 -12.79191448], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-26.09794673, -12.79191448]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[5.84880061e-07 2.92820086e-07 6.61964824e-08 ... 2.34723873e-06
#   1.45261503e-07 7.17487984e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.021203 +/- 0.000542) pb (2.554563 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-26.09794673, -12.79191448]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 0.9999999999999991
# 14:40 madminer.sampling    INFO    Sampling from parameter point 2 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [ 1.60956869 16.47712505], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([ 1.60956869, 16.47712505]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[2.58898668e-07 1.12940571e-08 1.07781736e-07 ... 3.61144181e-08
#   8.58068989e-09 3.29279092e-09]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.007457 +/- 0.000385) pb (5.161769 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([ 1.60956869, 16.47712505]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 0.9999999999999992
# 14:40 madminer.sampling    INFO    Sampling from parameter point 3 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [13.51705426 -3.92353836], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([13.51705426, -3.92353836]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[1.99274044e-07 1.32630253e-08 1.69160510e-09 ... 2.28461266e-07
#   2.65369252e-08 1.83378044e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.003664 +/- 0.000538) pb (14.687341 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([13.51705426, -3.92353836]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [13.51705426 -3.92353836]: (0.003664 +/- 0.000538) pb (14.687340942122024 %). Skipping these warnings in the future...
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000000009
# 14:40 madminer.sampling    INFO    Sampling from parameter point 4 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [7.79067557 4.22318578], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([7.79067557, 4.22318578]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[1.64684998e-09 2.05253709e-09 1.39978016e-08 ... 7.57698765e-08
#   5.40614282e-09 1.12765416e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.001536 +/- 0.000111) pb (7.198323 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([7.79067557, 4.22318578]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 0.9999999999999987
# 14:40 madminer.sampling    INFO    Sampling from parameter point 5 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [ -7.09483657 -14.57104855], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([ -7.09483657, -14.57104855]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[2.26775016e-09 1.67470049e-07 2.59612946e-09 ... 4.10183034e-07
#   1.26745440e-07 5.44162326e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.007560 +/- 0.000177) pb (2.345101 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([ -7.09483657, -14.57104855]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.000000000000005
# 14:40 madminer.sampling    INFO    Sampling from parameter point 6 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-6.93112579  4.6657322 ], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-6.93112579,  4.6657322 ]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[2.64437775e-07 1.76567571e-08 7.28231461e-08 ... 1.93458574e-07
#   9.94212792e-09 1.84390780e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.002213 +/- 0.000364) pb (16.428835 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-6.93112579,  4.6657322 ]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 0.9999999999999972
# 14:40 madminer.sampling    INFO    Sampling from parameter point 7 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-22.97027487  30.60106198], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-22.97027487,  30.60106198]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[3.09298340e-06 2.31063093e-08 5.54074693e-07 ... 1.06127025e-06
#   4.51479162e-08 2.28242616e-09]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.037352 +/- 0.001585) pb (4.243638 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-22.97027487,  30.60106198]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 0.9999999999999998
# 14:40 madminer.sampling    INFO    Sampling from parameter point 8 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [19.48001894  6.06738337], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([19.48001894,  6.06738337]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[1.67745183e-07 1.70428295e-08 1.89125615e-09 ... 7.36016269e-07
#   2.15056550e-09 5.70910895e-09]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.008253 +/- 0.000457) pb (5.538184 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([19.48001894,  6.06738337]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 0.9999999999999993
# 14:40 madminer.sampling    INFO    Sampling from parameter point 9 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-12.6640098  -18.32330267], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-12.6640098 , -18.32330267]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[2.10441811e-08 2.58077190e-07 4.62111847e-09 ... 8.94371176e-07
#   1.77021013e-07 7.01014957e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.013720 +/- 0.000132) pb (0.960586 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-12.6640098 , -18.32330267]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 0.9999999999999946
# 14:40 madminer.sampling    INFO    Sampling from parameter point 10 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [ 8.33884766 11.54805597], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([ 8.33884766, 11.54805597]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[2.07447518e-08 9.26306825e-09 4.09242062e-08 ... 1.47552198e-07
#   2.88885592e-09 4.70101474e-09]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# /Users/johannbrehmer/work/projects/madminer/madminer/madminer/analysis.py:395: RuntimeWarning: invalid value encountered in sqrt
#   xsec_uncertainties = xsec_uncertainties ** 0.5
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.004847 +/-  nan) pb ( nan %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([ 8.33884766, 11.54805597]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.000000000000001
# 14:40 madminer.sampling    INFO    Sampling from parameter point 11 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-33.0401002  -20.50329684], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-33.0401002 , -20.50329684]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[6.74950575e-07 5.02063571e-07 5.78899662e-08 ... 3.78341413e-06
#   2.52966277e-07 1.04196877e-07]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.037707 +/- 0.000568) pb (1.505249 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-33.0401002 , -20.50329684]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000000024
# 14:40 madminer.sampling    INFO    Sampling from parameter point 12 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-11.08585375  -0.53399456], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-11.08585375,  -0.53399456]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[2.82933514e-07 5.82576182e-08 6.20805102e-08 ... 4.71059255e-07
#   3.17834521e-08 2.93986890e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.003547 +/- 0.000367) pb (10.349940 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-11.08585375,  -0.53399456]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000000038
# 14:40 madminer.sampling    INFO    Sampling from parameter point 13 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [ 15.92711115 -10.41305906], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([ 15.92711115, -10.41305906]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[4.89026507e-07 3.45812898e-08 2.00837347e-08 ... 2.97836385e-07
#   5.87494829e-08 2.65769886e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.007435 +/- 0.000794) pb (10.683078 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([ 15.92711115, -10.41305906]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000000002
# 14:40 madminer.sampling    INFO    Sampling from parameter point 14 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-11.73682804  -7.144537  ], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-11.73682804,  -7.144537  ]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[1.50075291e-07 1.16080380e-07 3.14716044e-08 ... 6.11647993e-07
#   7.19798466e-08 4.25491700e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.005360 +/- 0.000224) pb (4.175955 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-11.73682804,  -7.144537  ]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.000000000000001
# 14:40 madminer.sampling    INFO    Sampling from parameter point 15 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-2.35943905 -8.54450696], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-2.35943905, -8.54450696]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[4.22064185e-10 8.12792614e-08 4.41214283e-09 ... 1.21916326e-07
#   6.92807544e-08 3.69795833e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.002470 +/- 0.000159) pb (6.444369 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-2.35943905, -8.54450696]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000000013
# 14:40 madminer.sampling    INFO    Sampling from parameter point 16 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-22.9391771    2.67294235], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-22.9391771 ,   2.67294235]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[1.08862686e-06 8.92349531e-08 1.65790308e-07 ... 1.51791246e-06
#   2.73330595e-08 3.34670964e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.013052 +/- 0.000842) pb (6.452679 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-22.9391771 ,   2.67294235]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000000002
# 14:40 madminer.sampling    INFO    Sampling from parameter point 17 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [17.4400383   1.72099323], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([17.4400383 ,  1.72099323]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[1.98307358e-07 6.87637196e-09 8.67564408e-10 ... 5.14783325e-07
#   7.03636652e-09 9.99044268e-09]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.005770 +/- 0.000511) pb (8.858422 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([17.4400383 ,  1.72099323]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000000002
# 14:40 madminer.sampling    INFO    Sampling from parameter point 18 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [15.67793268  7.90698647], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([15.67793268,  7.90698647]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[5.14675094e-08 1.37602874e-08 8.01814295e-09 ... 4.79953943e-07
#   1.93857253e-09 5.33972145e-09]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.006311 +/- 0.000275) pb (4.361245 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([15.67793268,  7.90698647]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 0.9999999999999983
# 14:40 madminer.sampling    INFO    Sampling from parameter point 19 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [27.79589147  8.56837205], nu = None (sampling)
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([27.79589147,  8.56837205]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[4.19151748e-07 5.39435393e-08 3.79632352e-09 ... 1.65041981e-06
#   4.94289835e-09 3.01021613e-09]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.017283 +/- 0.000664) pb (3.842738 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([27.79589147,  8.56837205]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.000000000000001
# 14:40 madminer.sampling    INFO    Sampling from parameter point 20 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [ -4.69828991 -19.1887145 ], nu = None (sampling)
# ...
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000002225
# 14:40 madminer.sampling    INFO    Sampling from parameter point 15 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [  8.14984522 -12.0636552 ], nu = None
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None (sampling)
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([  8.14984522, -12.0636552 ]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[2.11470388e-07 6.63055648e-08 7.03907094e-09 ... 3.74617270e-08
#   8.04908094e-08 3.50994707e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.004962 +/- 0.000585) pb (11.794719 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([  8.14984522, -12.0636552 ]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000002225
# 14:40 madminer.sampling    INFO    Sampling from parameter point 16 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [6.29644873 1.87133389], nu = None
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None (sampling)
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([6.29644873, 1.87133389]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[1.69616142e-09 5.71369146e-09 1.08553386e-08 ... 3.20746075e-08
#   1.10656175e-08 1.46610010e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.000774 +/- 0.000135) pb (17.393139 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([6.29644873, 1.87133389]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000002225
# 14:40 madminer.sampling    INFO    Sampling from parameter point 17 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-6.18212731 12.88977321], nu = None
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None (sampling)
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-6.18212731, 12.88977321]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[4.86904271e-07 5.23381971e-10 1.31022810e-07 ... 1.24039766e-07
#   1.16265652e-09 8.57451751e-09]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.005772 +/- 0.000555) pb (9.611048 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-6.18212731, 12.88977321]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000002225
# 14:40 madminer.sampling    INFO    Sampling from parameter point 18 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-7.67301993  2.98781601], nu = None
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None (sampling)
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-7.67301993,  2.98781601]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[2.48185562e-07 2.65201718e-08 6.60827339e-08 ... 2.39626557e-07
#   1.51999124e-08 2.12971737e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.002159 +/- 0.000345) pb (15.971993 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-7.67301993,  2.98781601]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000002225
# 14:40 madminer.sampling    INFO    Sampling from parameter point 19 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [24.99844242 16.77076463], nu = None
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None (sampling)
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([24.99844242, 16.77076463]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[1.17460322e-07 9.77626219e-08 1.31239590e-08 ... 1.52038792e-06
#   2.53418552e-08 1.22560517e-09]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.020037 +/- 0.000334) pb (1.665346 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([24.99844242, 16.77076463]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000002225
# 14:40 madminer.sampling    INFO    Sampling from parameter point 20 / 20
# 14:40 madminer.sampling    DEBUG   Drawing 2 events for the following parameter points:
# 14:40 madminer.sampling    DEBUG     0: theta = [-16.08658639   2.14914233], nu = None
# 14:40 madminer.sampling    DEBUG     1: theta = [0. 0.], nu = None (sampling)
# 14:40 madminer.analysis    DEBUG   Calculating cross sections for thetas = [array([-16.08658639,   2.14914233]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Nominal weights: [[6.10944067e-07 6.07050088e-08 1.10052999e-07 ... 8.18129218e-07
#   2.40436291e-08 2.87250727e-08]
#  [2.07260000e-08 2.07260000e-08 2.07260000e-08 ... 2.07260000e-08
#   2.07260000e-08 2.07260000e-08]]
# 14:40 madminer.analysis    DEBUG   Nuisance factors: 1.0
# 14:40 madminer.analysis    DEBUG   xsecs and uncertainties [pb]:
# 14:40 madminer.analysis    DEBUG     (0.006846 +/- 0.000602) pb (8.794277 %)
# 14:40 madminer.analysis    DEBUG     (0.000209 +/- 0.000002) pb (1.114210 %)
# 14:40 madminer.analysis    DEBUG   Calculating cross section gradients for thetas = [array([-16.08658639,   2.14914233]), 'sm'] and nus = [None, None]
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.analysis    DEBUG   Batch 1 with 8055 events
# 14:40 madminer.analysis    DEBUG   Distances from [0. 0.]: [0.0, 15.0, 15.0, 15.0, 15.0, 23.837736463862264]
# 14:40 madminer.analysis    DEBUG   n_events_generated_per_benchmark: [10041  1023  1127  1450  1389     0]
# 14:40 madminer.analysis    DEBUG   Sampling benchmark closest to [0. 0.]: 0
# 14:40 madminer.analysis    DEBUG   Sampling factors: [1. 1. 1. 1. 1. 1. 1.]
# 14:40 madminer.sampling    DEBUG     Cumulative probability (should be close to 1): 1.0000000000002225
# 14:40 madminer.sampling    INFO    Effective number of samples: mean 8055.0, with individual thetas ranging from 8055.0 to 8055.0
# 14:40 madminer.sampling    DEBUG   Effective number of samples for all thetas: [8055. 8055. 8055. 8055. 8055. 8055. 8055. 8055. 8055. 8055. 8055. 8055.
#  8055. 8055. 8055. 8055. 8055. 8055. 8055. 8055.]

# %% [markdown]
# For the evaluation we'll need a test sample:

# %%
_ = sampler.sample_test(
    theta=sampling.benchmark('sm'),
    n_samples=1000,
    folder='./data/samples',
    filename='test'
)
# Out:
# 14:32 madminer.sampling    INFO    Extracting evaluation sample. Sampling according to sm
# 14:32 madminer.sampling    INFO    Starting sampling serially
# 14:32 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 14:32 madminer.sampling    INFO    Effective number of samples: 19.046228721636165

# %% [markdown]
# You might notice the information about the "eeffective number of samples" in the output. This is defined as `1 / max_events(weights)`; the smaller it is, the bigger the statistical fluctuations from too large weights. Let's plot this over the parameter space:

# %%
cmin, cmax = 0, 60

cut = (y.flatten()==0)

fig = plt.figure(figsize=(5,4))

sc = plt.scatter(theta0[cut][:,0], theta0[cut][:,1], c=n_effective[cut],
                 s=60., cmap='viridis', vmin=cmin, vmax=cmax,
                 marker='o')

cb = plt.colorbar(sc)
cb.set_label('$n_{eff}$')

plt.xlim(-20.,20.)
plt.ylim(-20.,20.)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Plot cross section over parameter space

# %% [markdown]
# This is not strictly necessary, but we can also plot the cross section as a function of parameter space:

# %%
thetas_benchmarks, xsecs_benchmarks, xsec_errors_benchmarks = sampler.cross_sections(
    theta=sampling.benchmarks(['sm', 'w', 'morphing_basis_vector_2', 'morphing_basis_vector_3', 'morphing_basis_vector_4', 'morphing_basis_vector_5'])
)

thetas_morphing, xsecs_morphing, xsec_errors_morphing = sampler.cross_sections(
    theta=sampling.random_morphing_points(1000, [('gaussian', 0., 4.), ('gaussian', 0., 4.)])
)
# Out:
# 12:38 madminer.sampling    INFO    Starting cross-section calculation
# 12:38 madminer.sampling    INFO    Starting cross-section calculation

# %%
cmin, cmax = 0., 2.5 * np.mean(xsecs_morphing)

fig = plt.figure(figsize=(5,4))

sc = plt.scatter(thetas_morphing[:,0], thetas_morphing[:,1], c=xsecs_morphing,
            s=40., cmap='viridis', vmin=cmin, vmax=cmax,
            marker='o')

plt.scatter(thetas_benchmarks[:,0], thetas_benchmarks[:,1], c=xsecs_benchmarks,
            s=200., cmap='viridis', vmin=cmin, vmax=cmax, lw=2., edgecolor='black',
            marker='s')

cb = plt.colorbar(sc)
cb.set_label('xsec [pb]')

plt.xlim(-10.,10.)
plt.ylim(-10.,10.)
plt.tight_layout()
plt.show()

# %% [markdown]
# What  you see here is a morphing algorithm in action. We only asked MadGraph to calculate event weights (differential cross sections, or basically squared matrix elements) at six fixed parameter points (shown here as squares with black edges). But with our knowledge about the structure of the process we can interpolate any observable to any parameter point without loss (except that statistical uncertainties might increase)!

# %% [markdown]
# ## 3. Train likelihood ratio estimator

# %% [markdown]
# It's now time to build the neural network that estimates the likelihood ratio. The central object for this is the `madminer.ml.ParameterizedRatioEstimator` class. It defines functions that train, save, load, and evaluate the estimators.
#
# In the initialization, the keywords `n_hidden` and `activation` define the architecture of the (fully connected) neural network:

# %%
estimator = ParameterizedRatioEstimator(
    n_hidden=(100,),
    activation="tanh"
)

# %% [markdown]
# To train this model we will minimize the ALICES loss function described in ["Likelihood-free inference with an improved cross-entropy estimator"](https://arxiv.org/abs/1808.00973). Many alternatives, including RASCAL, are described in ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013) and ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020). There is also SCANDAL introduced in ["Mining gold from implicit models to improve likelihood-free inference"](https://arxiv.org/abs/1805.12244).

# %%
estimator.train(
    method='alices',
    theta='data/samples/theta0_train_ratio.npy',
    x='data/samples/x_train_ratio.npy',
    y='data/samples/y_train_ratio.npy',
    r_xz='data/samples/r_xz_train_ratio.npy',
    t_xz='data/samples/t_xz_train_ratio.npy',
    alpha=1.,
    n_epochs=20,
)

estimator.save('models/alices')
# Out:
# 12:39 madminer.ml          INFO    Starting training
# 12:39 madminer.ml          INFO      Method:                 alices
# 12:39 madminer.ml          INFO      alpha:                  1.0
# 12:39 madminer.ml          INFO      Batch size:             200
# 12:39 madminer.ml          INFO      Optimizer:              amsgrad
# 12:39 madminer.ml          INFO      Epochs:                 20
# 12:39 madminer.ml          INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 12:39 madminer.ml          INFO      Validation split:       0.25
# 12:39 madminer.ml          INFO      Early stopping:         True
# 12:39 madminer.ml          INFO      Scale inputs:           True
# 12:39 madminer.ml          INFO      Shuffle labels          False
# 12:39 madminer.ml          INFO      Samples:                all
# 12:39 madminer.ml          INFO    Loading training data
# 12:39 madminer.ml          INFO    Found 100000 samples with 2 parameters and 3 observables
# 12:39 madminer.ml          INFO    Rescaling inputs
# 12:39 madminer.ml          INFO    Creating model
# 12:39 madminer.ml          INFO    Training model
# 12:40 madminer.utils.ml.tr INFO    Epoch   1: train loss  0.53722 (improved_xe:  0.529, mse_score:  0.008)
# 12:40 madminer.utils.ml.tr INFO               val. loss   0.47846 (improved_xe:  0.471, mse_score:  0.008)
# 12:40 madminer.utils.ml.tr INFO    Epoch   2: train loss  0.46495 (improved_xe:  0.457, mse_score:  0.008)
# 12:40 madminer.utils.ml.tr INFO               val. loss   0.46243 (improved_xe:  0.456, mse_score:  0.007)
# 12:40 madminer.utils.ml.tr INFO    Epoch   3: train loss  0.45675 (improved_xe:  0.450, mse_score:  0.007)
# 12:40 madminer.utils.ml.tr INFO               val. loss   0.45558 (improved_xe:  0.449, mse_score:  0.007)
# 12:41 madminer.utils.ml.tr INFO    Epoch   4: train loss  0.45074 (improved_xe:  0.444, mse_score:  0.007)
# 12:41 madminer.utils.ml.tr INFO               val. loss   0.45110 (improved_xe:  0.445, mse_score:  0.006)
# 12:41 madminer.utils.ml.tr INFO    Epoch   5: train loss  0.44694 (improved_xe:  0.440, mse_score:  0.007)
# 12:41 madminer.utils.ml.tr INFO               val. loss   0.44824 (improved_xe:  0.442, mse_score:  0.006)
# 12:41 madminer.utils.ml.tr INFO    Epoch   6: train loss  0.44468 (improved_xe:  0.438, mse_score:  0.007)
# 12:41 madminer.utils.ml.tr INFO               val. loss   0.44668 (improved_xe:  0.440, mse_score:  0.006)
# 12:42 madminer.utils.ml.tr INFO    Epoch   7: train loss  0.44293 (improved_xe:  0.436, mse_score:  0.006)
# 12:42 madminer.utils.ml.tr INFO               val. loss   0.44494 (improved_xe:  0.439, mse_score:  0.006)
# 12:42 madminer.utils.ml.tr INFO    Epoch   8: train loss  0.44169 (improved_xe:  0.435, mse_score:  0.006)
# 12:42 madminer.utils.ml.tr INFO               val. loss   0.44364 (improved_xe:  0.438, mse_score:  0.006)
# 12:42 madminer.utils.ml.tr INFO    Epoch   9: train loss  0.44071 (improved_xe:  0.434, mse_score:  0.006)
# 12:42 madminer.utils.ml.tr INFO               val. loss   0.44300 (improved_xe:  0.437, mse_score:  0.006)
# 12:43 madminer.utils.ml.tr INFO    Epoch  10: train loss  0.43983 (improved_xe:  0.433, mse_score:  0.006)
# 12:43 madminer.utils.ml.tr INFO               val. loss   0.44193 (improved_xe:  0.436, mse_score:  0.006)
# 12:43 madminer.utils.ml.tr INFO    Epoch  11: train loss  0.43918 (improved_xe:  0.433, mse_score:  0.006)
# 12:43 madminer.utils.ml.tr INFO               val. loss   0.44143 (improved_xe:  0.435, mse_score:  0.006)
# 12:43 madminer.utils.ml.tr INFO    Epoch  12: train loss  0.43854 (improved_xe:  0.432, mse_score:  0.006)
# 12:43 madminer.utils.ml.tr INFO               val. loss   0.44105 (improved_xe:  0.435, mse_score:  0.006)
# 12:44 madminer.utils.ml.tr INFO    Epoch  13: train loss  0.43806 (improved_xe:  0.432, mse_score:  0.006)
# 12:44 madminer.utils.ml.tr INFO               val. loss   0.44065 (improved_xe:  0.435, mse_score:  0.006)
# 12:44 madminer.utils.ml.tr INFO    Epoch  14: train loss  0.43760 (improved_xe:  0.431, mse_score:  0.006)
# 12:44 madminer.utils.ml.tr INFO               val. loss   0.44031 (improved_xe:  0.434, mse_score:  0.006)
# 12:44 madminer.utils.ml.tr INFO    Epoch  15: train loss  0.43732 (improved_xe:  0.431, mse_score:  0.006)
# 12:44 madminer.utils.ml.tr INFO               val. loss   0.43996 (improved_xe:  0.434, mse_score:  0.006)
# 12:45 madminer.utils.ml.tr INFO    Epoch  16: train loss  0.43703 (improved_xe:  0.431, mse_score:  0.006)
# 12:45 madminer.utils.ml.tr INFO               val. loss   0.43952 (improved_xe:  0.434, mse_score:  0.006)
# 12:45 madminer.utils.ml.tr INFO    Epoch  17: train loss  0.43679 (improved_xe:  0.430, mse_score:  0.006)
# 12:45 madminer.utils.ml.tr INFO               val. loss   0.43930 (improved_xe:  0.433, mse_score:  0.006)
# 12:46 madminer.utils.ml.tr INFO    Epoch  18: train loss  0.43658 (improved_xe:  0.430, mse_score:  0.006)
# 12:46 madminer.utils.ml.tr INFO               val. loss   0.43914 (improved_xe:  0.433, mse_score:  0.006)
# 12:46 madminer.utils.ml.tr INFO    Epoch  19: train loss  0.43639 (improved_xe:  0.430, mse_score:  0.006)
# 12:46 madminer.utils.ml.tr INFO               val. loss   0.43902 (improved_xe:  0.433, mse_score:  0.006)
# 12:46 madminer.utils.ml.tr INFO    Epoch  20: train loss  0.43622 (improved_xe:  0.430, mse_score:  0.006)
# 12:46 madminer.utils.ml.tr INFO               val. loss   0.43886 (improved_xe:  0.433, mse_score:  0.006)
# 12:46 madminer.utils.ml.tr INFO    Early stopping did not improve performance

# %% [markdown]
# ## 4. Evaluate likelihood ratio estimator

# %% [markdown]
# `estimator.evaluate_log_likelihood_ratio(theta,x)` estimated the log likelihood ratio and the score for all combination between the given phase-space points `x` and parameters `theta`. That is, if given 100 events `x` and a grid of 25 `theta` points, it will return 25\*100 estimates for the log likelihood ratio and 25\*100 estimates for the score, both indexed by `[i_theta,i_x]`.

# %%
theta_each = np.linspace(-20.,20.,21)
theta0, theta1 = np.meshgrid(theta_each, theta_each)
theta_grid = np.vstack((theta0.flatten(), theta1.flatten())).T
np.save('data/samples/theta_grid.npy', theta_grid)

theta_denom = np.array([[0.,0.]])
np.save('data/samples/theta_ref.npy', theta_denom)

# %%
estimator.load('models/alices')

log_r_hat, _ = estimator.evaluate_log_likelihood_ratio(
    theta='data/samples/theta_grid.npy',
    x='data/samples/x_test.npy',
    evaluate_score=False
)

# %% [markdown]
# Let's look at the result:

# %%
bin_size = theta_each[1] - theta_each[0]
edges = np.linspace(theta_each[0] - bin_size/2, theta_each[-1] + bin_size/2, len(theta_each)+1)

fig = plt.figure(figsize=(6,5))
ax = plt.gca()

expected_llr = np.mean(log_r_hat,axis=1)
best_fit = theta_grid[np.argmin(-2.*expected_llr)]

cmin, cmax = np.min(-2*expected_llr), np.max(-2*expected_llr)
    
pcm = ax.pcolormesh(edges, edges, -2. * expected_llr.reshape((21,21)),
                    norm=matplotlib.colors.Normalize(vmin=cmin, vmax=cmax),
                    cmap='viridis_r')
cbar = fig.colorbar(pcm, ax=ax, extend='both')

plt.scatter(best_fit[0], best_fit[1], s=80., color='black', marker='*')

plt.xlabel(r'$\theta_0$')
plt.ylabel(r'$\theta_1$')
cbar.set_label(r'$\mathbb{E}_x [ -2\, \log \,\hat{r}(x | \theta, \theta_{SM}) ]$')

plt.tight_layout()
plt.show()

# %% [markdown]
# Note that in this tutorial our sample size was very small, and the network might not really have a chance to converge to the correct likelihood ratio function. So don't worry if you find a minimum that is not at the right point (the SM, i.e. the origin in this plot). Feel free to dial up the event numbers in the run card as well as the training samples and see what happens then!
