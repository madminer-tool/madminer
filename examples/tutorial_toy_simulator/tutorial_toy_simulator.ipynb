# %% [markdown]
# # Toy example
#
# Original notebook by Alexander Held, edited for the MadMiner repository by Johann Brehmer, Irina Espejo, Felix Kling, and Kyle Cranmer 2018-2019.

# %% [markdown]
# In this notebook, we use a simple toy example to demonstrate the machine learning and inference algorithms in MadMiner. This allows us to skip many of the more technical steps, and there's no dependency on MadGraph, Pythia, or Delphes.
#
# What this tutorial does not do, is explaining the inference methods. To understand what's happening, please have a look at ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013), which will explain the basic idea in just a few pages. If you really want to get down to the dirty details, ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020) has you covered.

# %% [markdown]
# ## Preparations

# %%
import os
import logging
import numpy as np
from scipy.stats import norm
from matplotlib import pyplot as plt

# %matplotlib inline

from madminer.ml import ParameterizedRatioEstimator

# %%
if not os.path.exists("data"):
    os.makedirs("data")

# %% [markdown]
# MadMiner uses the Python `logging` module to provide additional information and debugging output. You can choose how much of this output you want to see by switching the level in the following lines to `logging.DEBUG` or `logging.WARNING`.

# %%
# MadMiner output
logging.basicConfig(
    format="%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s",
    datefmt="%H:%M",
    level=logging.INFO,
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. A toy simulator

# %% [markdown]
# Our simulator depends on just one parameter `theta` and produces one-dimensional observables `x`. It is characterized by one latent variable `z`. "Running" the simulator consists of two steps:
# - "Hard process": a value of `z` is drawn from a normal distribution, where the mean depends on `theta`.
# - "Detector": a value for `x` is drawn from a normal distribution with mean equal to `z`. There is no explicit dependence on `theta`.
#
# As in the particle physics case, we assume that we can calculate the joint likelihood ratio `r(x, z | theta0, theta1)` as well as the joint score `t(x, z | theta)`, which depend explicitly on `z` (and where the "detector" part cancels).
#
# Here are some general settings (feel free to play with them):

# %%
z_std = 2.0
x_std = 1.0

# %% [markdown]
# The following function runs the simulator for a value of `theta` and calculates the joint likelihood ratio between `theta0` and `theta1` as well as the joint score at `theta_score`:

# %%
def simulate(theta, theta0=None, theta1=None, theta_score=None, npoints=None):
    # Draw latent variables z
    z = np.random.normal(loc=theta, scale=z_std, size=npoints)

    # Draw observables x
    x = np.random.normal(loc=z, scale=x_std, size=None)

    # Calculate joint likelihood ratio and joint score
    if theta0 is not None and theta1 is not None:
        r_xz = norm(loc=theta0, scale=z_std).pdf(z) / norm(loc=theta1, scale=z_std).pdf(z)
    else:
        r_xz = None

    if theta_score is not None:
        t_xz = (x - theta_score) / z_std**2
    else:
        t_xz = None

    return x, r_xz, t_xz

# %% [markdown]
# Usually the likelihood function `p(x|theta)` is intractable, but in this toy example it is just given by the convolution of two Gaussians, which is again a Gaussian. We will use this to validate the results later:

# %%
def calculate_likelihood_ratio(x, theta0, theta1=0.0):
    combined_std = (z_std**2 + x_std**2) ** 0.5
    r_x = norm(loc=theta0, scale=combined_std).pdf(x) / norm(loc=theta1, scale=combined_std).pdf(x)
    return r_x

# %% [markdown]
# Let's now visualize that: we run the simulation and plot the probability distributions $p(x | \theta_i)$. Additionally, we also plot the true log-likelihood ratio $\log\,r(x|\theta_0,\theta_1)$.

# %%
x0, _, _ = simulate(-2, npoints=10000)
x1, _, _ = simulate(2, npoints=10000)

xr = np.linspace(-4.0, 4.0, 100)
rx = np.log(calculate_likelihood_ratio(xr, -2, 2))

fig, ax1 = plt.subplots()
fig.set_size_inches(5, 5)
ax1.set_xlabel("$x$", size=14)
ax1.hist(x0, bins=50, range=(-10, 10.0), histtype="step", label=r"$p(x | \theta_0)$", density=True)
ax1.hist(x1, bins=50, range=(-10, 10.0), histtype="step", label=r"$p(x | \theta_1)$", density=True)
ax1.set_ylabel(r"$p(x|\theta)$", size=14)
ax1.legend(loc=2)

ax2 = ax1.twinx()
ax2.plot(xr, rx, color="black", label=r"$\log\,r(x|\theta_0,\theta_1)$")
ax2.set_ylabel(r"$\log\,r(x|\theta_0,\theta_1)$", size=14)
ax2.legend(loc=1)

fig.savefig("true_log_likelihood_ratio.png", dpi=300)

# %% [markdown]
# ## 2. Run the simulation and generate training data

# %% [markdown]
# First, we define the parameter points we want to use for training: `theta0` is uniformly distributed while the reference model `theta1` is fixed at zero.

# %%
# number of parameter points to train
n_param_points = 50000

# numerator, uniform prior
theta0 = np.random.uniform(low=-4.0, high=4.0, size=n_param_points)

# denominator: fixed at 0
theta1 = np.zeros(shape=n_param_points)

# %% [markdown]
# We then run the simulator (one sample per parameter point). Remember that `simulate(theta, theta0, theta1, theta_score)` generates data `x` following a theory with `theta` and then evaluates the joint likelihood ratio `r(x,z|theta0,theta1)` and the join score `t(x,z|theta_score)` for each data point.

# %%
# Sample from theta0
x_from_theta0, r_xz_from_theta0, t_xz_from_theta0 = simulate(theta0, theta0, theta1, theta0)

# Sample from theta1
x_from_theta1, r_xz_from_theta1, t_xz_from_theta1 = simulate(theta1, theta0, theta1, theta0)

# %% [markdown]
# Now we combine and reshape the results (nothing interesting happening here) and save everything to files, so that we can load it later.

# %%
# Combine results and reshape
x_train = np.hstack((x_from_theta0, x_from_theta1)).reshape(-1, 1)
r_xz_train = np.hstack((r_xz_from_theta0, r_xz_from_theta1)).reshape(-1, 1)
t_xz_train = np.hstack((t_xz_from_theta0, t_xz_from_theta1)).reshape(-1, 1)
y_train = np.hstack((np.zeros_like(x_from_theta0), np.ones_like(np.ones_like(x_from_theta1)))).reshape(-1, 1)
theta0_train = np.hstack((theta0, theta0)).reshape(-1, 1)

# Save to file
np.save("data/theta0_train.npy", theta0_train)
np.save("data/x_train.npy", x_train)
np.save("data/y_train.npy", y_train)
np.save("data/r_xz_train.npy", r_xz_train)
np.save("data/t_xz_train.npy", t_xz_train)

# %% [markdown]
# ## 3. Model training

# %% [markdown]
# Let's train two neural networks to estimate the likelihood ratio. For one we use the CARL method introduced in ["Approximating Likelihood Ratios with Calibrated Discriminative Classifiers"](https://arxiv.org/abs/1506.02169), for the other the new ALICES method introduced in ["Likelihood-free inference with an improved cross-entropy estimator"](https://arxiv.org/abs/1808.00973).

# %%
carl = ParameterizedRatioEstimator(n_hidden=(20, 20))

carl.train(
    method="carl",
    x="data/x_train.npy",
    y="data/y_train.npy",
    theta="data/theta0_train.npy",
    n_epochs=20,
)

carl.save("models/carl")
# Out:
# 01:35 madminer.ml.paramete INFO    Starting training
# 01:35 madminer.ml.paramete INFO      Method:                 carl
# 01:35 madminer.ml.paramete INFO      Batch size:             128
# 01:35 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 01:35 madminer.ml.paramete INFO      Epochs:                 20
# 01:35 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 01:35 madminer.ml.paramete INFO      Validation split:       0.25
# 01:35 madminer.ml.paramete INFO      Early stopping:         True
# 01:35 madminer.ml.paramete INFO      Scale inputs:           True
# 01:35 madminer.ml.paramete INFO      Scale parameters:       True
# 01:35 madminer.ml.paramete INFO      Shuffle labels          False
# 01:35 madminer.ml.paramete INFO      Samples:                all
# 01:35 madminer.ml.paramete INFO    Loading training data
# 01:35 madminer.utils.vario INFO      Loading data/theta0_train.npy into RAM
# 01:35 madminer.utils.vario INFO      Loading data/x_train.npy into RAM
# 01:35 madminer.utils.vario INFO      Loading data/y_train.npy into RAM
# 01:35 madminer.ml.paramete INFO    Found 100000 samples with 1 parameters and 1 observables
# 01:35 madminer.ml.base     INFO    Setting up input rescaling
# 01:35 madminer.ml.paramete INFO    Rescaling parameters
# 01:35 madminer.ml.base     INFO    Setting up parameter rescaling
# 01:35 madminer.ml.paramete INFO    Creating model
# 01:35 madminer.ml.paramete INFO    Training model
# 01:35 madminer.utils.ml.tr INFO    Training on GPU with single precision
# 01:35 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.62294 (xe:  0.623)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58951 (xe:  0.623)
# 01:35 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.59054 (xe:  0.591)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58686 (xe:  0.591)
# 01:35 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.58905 (xe:  0.589)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58628 (xe:  0.589)
# 01:35 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.58822 (xe:  0.588)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58522 (xe:  0.588)
# 01:35 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.58775 (xe:  0.588)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58555 (xe:  0.588)
# 01:35 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.58749 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58539 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO      Epoch   7: train loss  0.58719 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58463 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.58712 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58508 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO      Epoch   9: train loss  0.58675 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58523 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.58663 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58588 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO      Epoch  11: train loss  0.58653 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58393 (xe:  0.587)
# 01:35 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.58637 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58397 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO      Epoch  13: train loss  0.58634 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58396 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO      Epoch  14: train loss  0.58622 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58418 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO      Epoch  15: train loss  0.58620 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58417 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.58624 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58400 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO      Epoch  17: train loss  0.58611 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58396 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO      Epoch  18: train loss  0.58606 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58443 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO      Epoch  19: train loss  0.58600 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58426 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.58602 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO                 val. loss   0.58368 (xe:  0.586)
# 01:35 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 01:35 madminer.utils.ml.tr INFO    Training time spend on:
# 01:35 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 01:35 madminer.utils.ml.tr INFO                                   ALL:   0.02h
# 01:35 madminer.utils.ml.tr INFO                            check data:   0.00h
# 01:35 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 01:35 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 01:35 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 01:35 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 01:35 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 01:35 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 01:35 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 01:35 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 01:35 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 01:35 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 01:35 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 01:35 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 01:35 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 01:35 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 01:35 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 01:35 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 01:35 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 01:35 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 01:35 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 01:35 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 01:35 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 01:35 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 01:35 madminer.ml.base     INFO    Saving model to models/carl

# %%
alices = ParameterizedRatioEstimator(n_hidden=(20, 20))

alices.train(
    method="alices",
    x="data/x_train.npy",
    y="data/y_train.npy",
    theta="data/theta0_train.npy",
    r_xz="data/r_xz_train.npy",
    t_xz="data/t_xz_train.npy",
    alpha=0.1,
    n_epochs=20,
)

alices.save("models/alices")
# Out:
# 01:36 madminer.ml.paramete INFO    Starting training
# 01:36 madminer.ml.paramete INFO      Method:                 alices
# 01:36 madminer.ml.paramete INFO      alpha:                  0.1
# 01:36 madminer.ml.paramete INFO      Batch size:             128
# 01:36 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 01:36 madminer.ml.paramete INFO      Epochs:                 20
# 01:36 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 01:36 madminer.ml.paramete INFO      Validation split:       0.25
# 01:36 madminer.ml.paramete INFO      Early stopping:         True
# 01:36 madminer.ml.paramete INFO      Scale inputs:           True
# 01:36 madminer.ml.paramete INFO      Scale parameters:       True
# 01:36 madminer.ml.paramete INFO      Shuffle labels          False
# 01:36 madminer.ml.paramete INFO      Samples:                all
# 01:36 madminer.ml.paramete INFO    Loading training data
# 01:36 madminer.utils.vario INFO      Loading data/theta0_train.npy into RAM
# 01:36 madminer.utils.vario INFO      Loading data/x_train.npy into RAM
# 01:36 madminer.utils.vario INFO      Loading data/y_train.npy into RAM
# 01:36 madminer.utils.vario INFO      Loading data/r_xz_train.npy into RAM
# 01:36 madminer.utils.vario INFO      Loading data/t_xz_train.npy into RAM
# 01:36 madminer.ml.paramete INFO    Found 100000 samples with 1 parameters and 1 observables
# 01:36 madminer.ml.base     INFO    Setting up input rescaling
# 01:36 madminer.ml.paramete INFO    Rescaling parameters
# 01:36 madminer.ml.base     INFO    Setting up parameter rescaling
# 01:36 madminer.ml.paramete INFO    Creating model
# 01:36 madminer.ml.paramete INFO    Training model
# 01:36 madminer.utils.ml.tr INFO    Training on GPU with single precision
# 01:36 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.63055 (improved_xe:  0.606, mse_score:  0.246)
# 01:36 madminer.utils.ml.tr INFO                 val. loss   0.59107 (improved_xe:  0.606, mse_score:  0.246)
# 01:36 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.58862 (improved_xe:  0.585, mse_score:  0.033)
# 01:36 madminer.utils.ml.tr INFO                 val. loss   0.58667 (improved_xe:  0.585, mse_score:  0.033)
# 01:36 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.58629 (improved_xe:  0.585, mse_score:  0.017)
# 01:36 madminer.utils.ml.tr INFO                 val. loss   0.58593 (improved_xe:  0.585, mse_score:  0.017)
# 01:36 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.58564 (improved_xe:  0.584, mse_score:  0.013)
# 01:36 madminer.utils.ml.tr INFO                 val. loss   0.58499 (improved_xe:  0.584, mse_score:  0.013)
# 01:36 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.58544 (improved_xe:  0.584, mse_score:  0.012)
# 01:36 madminer.utils.ml.tr INFO                 val. loss   0.58528 (improved_xe:  0.584, mse_score:  0.012)
# 01:36 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.58535 (improved_xe:  0.584, mse_score:  0.011)
# 01:36 madminer.utils.ml.tr INFO                 val. loss   0.58520 (improved_xe:  0.584, mse_score:  0.011)
# 01:36 madminer.utils.ml.tr INFO      Epoch   7: train loss  0.58526 (improved_xe:  0.584, mse_score:  0.010)
# 01:36 madminer.utils.ml.tr INFO                 val. loss   0.58504 (improved_xe:  0.584, mse_score:  0.010)
# 01:36 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.58521 (improved_xe:  0.584, mse_score:  0.010)
# 01:36 madminer.utils.ml.tr INFO                 val. loss   0.58499 (improved_xe:  0.584, mse_score:  0.010)
# 01:36 madminer.utils.ml.tr INFO      Epoch   9: train loss  0.58516 (improved_xe:  0.584, mse_score:  0.010)
# 01:36 madminer.utils.ml.tr INFO                 val. loss   0.58489 (improved_xe:  0.584, mse_score:  0.010)
# 01:37 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.58513 (improved_xe:  0.584, mse_score:  0.010)
# 01:37 madminer.utils.ml.tr INFO                 val. loss   0.58495 (improved_xe:  0.584, mse_score:  0.010)
# 01:37 madminer.utils.ml.tr INFO      Epoch  11: train loss  0.58510 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO                 val. loss   0.58525 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.58509 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO                 val. loss   0.58498 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO      Epoch  13: train loss  0.58506 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO                 val. loss   0.58499 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO      Epoch  14: train loss  0.58504 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO                 val. loss   0.58477 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO      Epoch  15: train loss  0.58503 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO                 val. loss   0.58480 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.58500 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO                 val. loss   0.58497 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO      Epoch  17: train loss  0.58500 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO                 val. loss   0.58487 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO      Epoch  18: train loss  0.58500 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO                 val. loss   0.58481 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO      Epoch  19: train loss  0.58499 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO                 val. loss   0.58482 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.58497 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO                 val. loss   0.58486 (improved_xe:  0.584, mse_score:  0.009)
# 01:37 madminer.utils.ml.tr INFO    Early stopping after epoch 14, with loss  0.58477 compared to final loss  0.58486
# 01:37 madminer.utils.ml.tr INFO    Training time spend on:
# 01:37 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 01:37 madminer.utils.ml.tr INFO                                   ALL:   0.02h
# 01:37 madminer.utils.ml.tr INFO                            check data:   0.00h
# 01:37 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 01:37 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 01:37 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 01:37 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 01:37 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 01:37 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 01:37 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 01:37 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 01:37 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 01:37 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 01:37 madminer.utils.ml.tr INFO                 training forward pass:   0.01h
# 01:37 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 01:37 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 01:37 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 01:37 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 01:37 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 01:37 madminer.utils.ml.tr INFO                        optimizer step:   0.01h
# 01:37 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 01:37 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 01:37 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 01:37 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 01:37 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 01:37 madminer.ml.base     INFO    Saving model to models/alices

# %% [markdown]
# We can also try a little bit of mixing and matching -- let's train a model with CARL first and then with ALICES:

# %%
mix = ParameterizedRatioEstimator(n_hidden=(20, 20))

mix.train(
    method="carl",
    x="data/x_train.npy",
    y="data/y_train.npy",
    theta="data/theta0_train.npy",
    n_epochs=10,
    initial_lr=0.001,
    final_lr=0.0003,
)

mix.train(
    method="alices",
    x="data/x_train.npy",
    y="data/y_train.npy",
    theta="data/theta0_train.npy",
    r_xz="data/r_xz_train.npy",
    t_xz="data/t_xz_train.npy",
    alpha=0.1,
    n_epochs=10,
    initial_lr=0.0003,
    final_lr=0.0001,
)

mix.save("models/mix")
# Out:
# 01:38 madminer.ml.paramete INFO    Starting training
# 01:38 madminer.ml.paramete INFO      Method:                 carl
# 01:38 madminer.ml.paramete INFO      Batch size:             128
# 01:38 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 01:38 madminer.ml.paramete INFO      Epochs:                 10
# 01:38 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0003
# 01:38 madminer.ml.paramete INFO      Validation split:       0.25
# 01:38 madminer.ml.paramete INFO      Early stopping:         True
# 01:38 madminer.ml.paramete INFO      Scale inputs:           True
# 01:38 madminer.ml.paramete INFO      Scale parameters:       True
# 01:38 madminer.ml.paramete INFO      Shuffle labels          False
# 01:38 madminer.ml.paramete INFO      Samples:                all
# 01:38 madminer.ml.paramete INFO    Loading training data
# 01:38 madminer.utils.vario INFO      Loading data/theta0_train.npy into RAM
# 01:38 madminer.utils.vario INFO      Loading data/x_train.npy into RAM
# 01:38 madminer.utils.vario INFO      Loading data/y_train.npy into RAM
# 01:38 madminer.ml.paramete INFO    Found 100000 samples with 1 parameters and 1 observables
# 01:38 madminer.ml.base     INFO    Setting up input rescaling
# 01:38 madminer.ml.paramete INFO    Rescaling parameters
# 01:38 madminer.ml.base     INFO    Setting up parameter rescaling
# 01:38 madminer.ml.paramete INFO    Creating model
# 01:38 madminer.ml.paramete INFO    Training model
# 01:38 madminer.utils.ml.tr INFO    Training on GPU with single precision
# 01:38 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.62567 (xe:  0.626)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.59063 (xe:  0.626)
# 01:38 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.58959 (xe:  0.590)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58720 (xe:  0.590)
# 01:38 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.58807 (xe:  0.588)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58650 (xe:  0.588)
# 01:38 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.58709 (xe:  0.587)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58618 (xe:  0.587)
# 01:38 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.58680 (xe:  0.587)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58638 (xe:  0.587)
# 01:38 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.58649 (xe:  0.586)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58642 (xe:  0.586)
# 01:38 madminer.utils.ml.tr INFO      Epoch   7: train loss  0.58610 (xe:  0.586)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58441 (xe:  0.586)
# 01:38 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.58600 (xe:  0.586)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58467 (xe:  0.586)
# 01:38 madminer.utils.ml.tr INFO      Epoch   9: train loss  0.58580 (xe:  0.586)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58478 (xe:  0.586)
# 01:38 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.58558 (xe:  0.586)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58476 (xe:  0.586)
# 01:38 madminer.utils.ml.tr INFO    Early stopping after epoch 7, with loss  0.58441 compared to final loss  0.58476
# 01:38 madminer.utils.ml.tr INFO    Training time spend on:
# 01:38 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 01:38 madminer.utils.ml.tr INFO                                   ALL:   0.01h
# 01:38 madminer.utils.ml.tr INFO                            check data:   0.00h
# 01:38 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 01:38 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 01:38 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 01:38 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 01:38 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 01:38 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 01:38 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 01:38 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 01:38 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 01:38 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 01:38 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 01:38 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 01:38 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 01:38 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 01:38 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 01:38 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 01:38 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 01:38 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 01:38 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 01:38 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 01:38 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 01:38 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 01:38 madminer.ml.paramete INFO    Starting training
# 01:38 madminer.ml.paramete INFO      Method:                 alices
# 01:38 madminer.ml.paramete INFO      alpha:                  0.1
# 01:38 madminer.ml.paramete INFO      Batch size:             128
# 01:38 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 01:38 madminer.ml.paramete INFO      Epochs:                 10
# 01:38 madminer.ml.paramete INFO      Learning rate:          0.0003 initially, decaying to 0.0001
# 01:38 madminer.ml.paramete INFO      Validation split:       0.25
# 01:38 madminer.ml.paramete INFO      Early stopping:         True
# 01:38 madminer.ml.paramete INFO      Scale inputs:           True
# 01:38 madminer.ml.paramete INFO      Scale parameters:       True
# 01:38 madminer.ml.paramete INFO      Shuffle labels          False
# 01:38 madminer.ml.paramete INFO      Samples:                all
# 01:38 madminer.ml.paramete INFO    Loading training data
# 01:38 madminer.utils.vario INFO      Loading data/theta0_train.npy into RAM
# 01:38 madminer.utils.vario INFO      Loading data/x_train.npy into RAM
# 01:38 madminer.utils.vario INFO      Loading data/y_train.npy into RAM
# 01:38 madminer.utils.vario INFO      Loading data/r_xz_train.npy into RAM
# 01:38 madminer.utils.vario INFO      Loading data/t_xz_train.npy into RAM
# 01:38 madminer.ml.paramete INFO    Found 100000 samples with 1 parameters and 1 observables
# 01:38 madminer.ml.base     INFO    Input rescaling already defined. To overwrite, call initialize_input_transform(x, overwrite=True).
# 01:38 madminer.ml.paramete INFO    Rescaling parameters
# 01:38 madminer.ml.base     INFO    Setting up parameter rescaling
# 01:38 madminer.ml.paramete INFO    Training model
# 01:38 madminer.utils.ml.tr INFO    Training on GPU with single precision
# 01:38 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.59055 (improved_xe:  0.585, mse_score:  0.057)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58908 (improved_xe:  0.585, mse_score:  0.057)
# 01:38 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.58739 (improved_xe:  0.585, mse_score:  0.028)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58751 (improved_xe:  0.585, mse_score:  0.028)
# 01:38 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.58649 (improved_xe:  0.584, mse_score:  0.021)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58670 (improved_xe:  0.584, mse_score:  0.021)
# 01:38 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.58600 (improved_xe:  0.584, mse_score:  0.018)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58638 (improved_xe:  0.584, mse_score:  0.018)
# 01:38 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.58576 (improved_xe:  0.584, mse_score:  0.016)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58630 (improved_xe:  0.584, mse_score:  0.016)
# 01:38 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.58555 (improved_xe:  0.584, mse_score:  0.014)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58622 (improved_xe:  0.584, mse_score:  0.014)
# 01:38 madminer.utils.ml.tr INFO      Epoch   7: train loss  0.58544 (improved_xe:  0.584, mse_score:  0.014)
# 01:38 madminer.utils.ml.tr INFO                 val. loss   0.58601 (improved_xe:  0.584, mse_score:  0.014)
# 01:39 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.58535 (improved_xe:  0.584, mse_score:  0.013)
# 01:39 madminer.utils.ml.tr INFO                 val. loss   0.58606 (improved_xe:  0.584, mse_score:  0.013)
# 01:39 madminer.utils.ml.tr INFO      Epoch   9: train loss  0.58529 (improved_xe:  0.584, mse_score:  0.012)
# 01:39 madminer.utils.ml.tr INFO                 val. loss   0.58591 (improved_xe:  0.584, mse_score:  0.012)
# 01:39 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.58523 (improved_xe:  0.584, mse_score:  0.012)
# 01:39 madminer.utils.ml.tr INFO                 val. loss   0.58585 (improved_xe:  0.584, mse_score:  0.012)
# 01:39 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 01:39 madminer.utils.ml.tr INFO    Training time spend on:
# 01:39 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 01:39 madminer.utils.ml.tr INFO                                   ALL:   0.01h
# 01:39 madminer.utils.ml.tr INFO                            check data:   0.00h
# 01:39 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 01:39 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 01:39 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 01:39 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 01:39 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 01:39 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 01:39 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 01:39 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 01:39 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 01:39 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 01:39 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 01:39 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 01:39 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 01:39 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 01:39 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 01:39 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 01:39 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 01:39 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 01:39 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 01:39 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 01:39 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 01:39 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 01:39 madminer.ml.base     INFO    Saving model to models/mix

# %% [markdown]
# ## 4. Generate evaluation data

# %% [markdown]
# Let us now generate some test data, which is sampled corresponding to `theta=1`

# %%
n_param_points_test = 1000  # number of parameter points to test
theta_test = 1.0 * np.ones(shape=n_param_points_test).reshape(-1, 1)

# %% [markdown]
# Run the simulator to get observations:

# %%
x_test, _, _ = simulate(theta_test)
np.save("data/x_test.npy", x_test)

# %% [markdown]
# We want to evaluate the expected likelihood ratio on a range of parameter points:

# %%
theta_grid = np.linspace(-5.0, 5.0, 100).reshape(-1, 1)
np.save("data/theta_grid.npy", theta_grid)

# %% [markdown]
# In this toy example, we can calculate the true likelihood ratio. We will save the expected log likelihood ratio (multiplied with a conventional factor of -2):

# %%
all_log_r_test_true = []
nllr_test_true = []

for theta in theta_grid:
    log_r = np.log(calculate_likelihood_ratio(x_test, theta))
    nllr_test_true.append(-2.0 * np.mean(log_r))
    all_log_r_test_true.append(log_r)

all_log_r_test_true = np.asarray(all_log_r_test_true).reshape((100, n_param_points_test))
nllr_test_true = np.asarray(nllr_test_true)

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# It's time to evaluate our likelihood ratio estimators!

# %%
carl = ParameterizedRatioEstimator()
carl.load("models/carl")

log_r, _ = carl.evaluate(
    theta="data/theta_grid.npy",
    x="data/x_test.npy",
    evaluate_score=False,
)

nllr_test_carl = -2.0 * np.mean(log_r, axis=1)
mse_carl = np.mean((all_log_r_test_true - log_r) ** 2)
print(f"MSE: {mse_carl}")
# Out:
# 01:43 madminer.ml.base     INFO    Loading model from models/carl
# 01:43 madminer.utils.vario INFO      Loading data/x_test.npy into RAM
# 01:43 madminer.utils.vario INFO      Loading data/theta_grid.npy into RAM
# MSE: 0.3411976410503404

# %%
alices = ParameterizedRatioEstimator()
alices.load("models/alices")

log_r, _ = alices.evaluate(
    theta="data/theta_grid.npy",
    x="data/x_test.npy",
    evaluate_score=False,
)

nllr_test_alices = -2.0 * np.mean(log_r, axis=1)
mse_alices = np.mean((all_log_r_test_true - log_r) ** 2)
print(f"MSE: {mse_alices}")
# Out:
# 01:43 madminer.ml.base     INFO    Loading model from models/alices
# 01:43 madminer.utils.vario INFO      Loading data/x_test.npy into RAM
# 01:43 madminer.utils.vario INFO      Loading data/theta_grid.npy into RAM
# MSE: 0.046414756496217326

# %%
mix = ParameterizedRatioEstimator()
mix.load("models/mix")

log_r, _ = mix.evaluate(
    theta="data/theta_grid.npy",
    x="data/x_test.npy",
    evaluate_score=False,
)

nllr_test_mix = -2.0 * np.mean(log_r, axis=1)
mse_mix = np.mean((all_log_r_test_true - log_r) ** 2)
print(f"MSE: {mse_mix}")
# Out:
# 01:43 madminer.ml.base     INFO    Loading model from models/mix
# 01:43 madminer.utils.vario INFO      Loading data/x_test.npy into RAM
# 01:43 madminer.utils.vario INFO      Loading data/theta_grid.npy into RAM
# MSE: 0.09629278233996805

# %% [markdown]
# This is the expected log likelihood ratio over parameter space:

# %%
best_fit_alices = float(theta_grid[np.argmin(nllr_test_alices)])
best_fit_carl = float(theta_grid[np.argmin(nllr_test_carl)])
best_fit_mix = float(theta_grid[np.argmin(nllr_test_mix)])

fig, ax = plt.subplots(figsize=(5, 5))

ax.plot(
    theta_grid,
    nllr_test_true,
    ls="--",
    color="black",
    label=r"Ground truth ($\theta = 1.0$)",
)
ax.plot(
    theta_grid,
    nllr_test_carl,
    label=r"CARL ($\hat{\theta} = " + f"{best_fit_carl:.3f}$)",
)
ax.plot(
    theta_grid,
    nllr_test_alices,
    label=r"ALICES ($\hat{\theta} = " + f"{best_fit_alices:.3f}$)",
)
ax.plot(
    theta_grid,
    nllr_test_mix,
    label=r"CARL-ALICES ($\hat{\theta} = " + f"{best_fit_mix:.3f}$)",
)

ax.set_xlabel(r"$\theta$", size=14)
ax.set_ylabel(r"$\mathbb{E}_x [ -2\, \log \,r(x | \theta, \theta_{1}) ]$", size=14)

ax.legend()
fig.tight_layout()

fig.savefig("expected_log_likelihood_ratio.png", dpi=300)
# Out:
# /tmp/ipykernel_507700/2064074188.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   best_fit_alices = float(theta_grid[np.argmin(nllr_test_alices)])
# /tmp/ipykernel_507700/2064074188.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   best_fit_carl = float(theta_grid[np.argmin(nllr_test_carl)])
# /tmp/ipykernel_507700/2064074188.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   best_fit_mix = float(theta_grid[np.argmin(nllr_test_mix)])

# %% [markdown]
# You should see that the new ALICES approach leads to a better approximation of the true likelihood ratio than the CARL estimate. Note that we only trained in the parameter range `(-4, 4)`, so the deviations at the left and right of the plot are to be expected.
